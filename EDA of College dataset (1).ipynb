# %%
import pandas as pd

# %%
#DataFrame called dataset

dataset = pd.read_csv("College data.csv")
dataset
# Out:
#     Private   Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0       Yes   1660    1232     721         23         52         2885
# 1       Yes   2186    1924     512         16         29         2683
# 2       Yes   1428    1097     336         22         50         1036
# 3       Yes    417     349     137         60         89          510
# 4       Yes    193     146      55         16         44          249
# ..      ...    ...     ...     ...        ...        ...          ...
# 772      No   2197    1515     543          4         26         3089
# 773     Yes   1959    1805     695         24         47         2849
# 774     Yes   2097    1915     695         34         61         2793
# 775     Yes  10705    2453    1317         95         99         5217
# 776     Yes   2989    1855     691         28         63         2988
#
#      P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# 0            537      7440        3300    450      2200   70        78
# 1           1227     12280        6450    750      1500   29        30
# 2             99     11250        3750    400      1165   53        66
# 3             63     12960        5450    450       875   92        97
# 4            869      7560        4120    800      1500   76        72
# ..           ...       ...         ...    ...       ...  ...       ...
# 772         2029      6797        3900    500      1200   60        60
# 773         1107     11520        4960    600      1250   73        75
# 774          166      6900        4200    617       781   67        75
# 775           83     19840        6510    630      2115   96        96
# 776         1726      4990        3560    500      1250   75        75
#
#      S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0         18.1           12    7041         60
# 1         12.2           16   10527         56
# 2         12.9           30    8735         54
# 3          7.7           37   19016         59
# 4         11.9            2   10922         15
# ..         ...          ...     ...        ...
# 772       21.0           14    4469         40
# 773       13.3           31    9189         83
# 774       14.4           20    8323         49
# 775        5.8           49   40386         99
# 776       18.1           28    4509         99
#
# [777 rows x 18 columns]

# %% [markdown]
# # Exploring DataFrames in Pandas.

# %% [markdown]
# # 1. Print a sample of dataframe.

# %%
dataset.head(10)
# Out:
#   Private  Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0     Yes  1660    1232     721         23         52         2885
# 1     Yes  2186    1924     512         16         29         2683
# 2     Yes  1428    1097     336         22         50         1036
# 3     Yes   417     349     137         60         89          510
# 4     Yes   193     146      55         16         44          249
# 5     Yes   587     479     158         38         62          678
# 6     Yes   353     340     103         17         45          416
# 7     Yes  1899    1720     489         37         68         1594
# 8     Yes  1038     839     227         30         63          973
# 9     Yes   582     498     172         21         44          799
#
#    P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# 0          537      7440        3300    450      2200   70        78
# 1         1227     12280        6450    750      1500   29        30
# 2           99     11250        3750    400      1165   53        66
# 3           63     12960        5450    450       875   92        97
# 4          869      7560        4120    800      1500   76        72
# 5           41     13500        3335    500       675   67        73
# 6          230     13290        5720    500      1500   90        93
# 7           32     13868        4826    450       850   89       100
# 8          306     15595        4400    300       500   79        84
# 9           78     10468        3380    660      1800   40        41
#
#    S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0       18.1           12    7041         60
# 1       12.2           16   10527         56
# 2       12.9           30    8735         54
# 3        7.7           37   19016         59
# 4       11.9            2   10922         15
# 5        9.4           11    9727         55
# 6       11.5           26    8861         63
# 7       13.7           37   11487         73
# 8       11.3           23   11644         80
# 9       11.5           15    8991         52

# %%
dataset.tail(10)
# Out:
#     Private   Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 767      No   2320    1805     769         24         61         3395
# 768     Yes    152     128      75         17         41          282
# 769     Yes   1979    1739     575         42         68         1980
# 770     Yes   1501     935     273         51         83         1059
# 771     Yes   2768    2314     682         49         86         2802
# 772      No   2197    1515     543          4         26         3089
# 773     Yes   1959    1805     695         24         47         2849
# 774     Yes   2097    1915     695         34         61         2793
# 775     Yes  10705    2453    1317         95         99         5217
# 776     Yes   2989    1855     691         28         63         2988
#
#      P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# 767          670      6400        3392    580      2150   71        80
# 768           22      9100        3700    500      1400   48        48
# 769          144     15948        4404    400       800   82        95
# 770           34     12680        4150    605      1440   91        92
# 771           86     15884        5370    530       730   92        94
# 772         2029      6797        3900    500      1200   60        60
# 773         1107     11520        4960    600      1250   73        75
# 774          166      6900        4200    617       781   67        75
# 775           83     19840        6510    630      2115   96        96
# 776         1726      4990        3560    500      1250   75        75
#
#      S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 767       12.8           26    6729         59
# 768        8.5           26    8960         50
# 769       12.8           29   10414         78
# 770       15.3           42    7875         75
# 771       15.2           34   10774         82
# 772       21.0           14    4469         40
# 773       13.3           31    9189         83
# 774       14.4           20    8323         49
# 775        5.8           49   40386         99
# 776       18.1           28    4509         99

# %% [markdown]
# # 2. Print random data samples of dataframe

# %%
dataset.sample(5)
# Out:
#     Private  Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 16      Yes  4302     992     418         83         96         1593
# 163     Yes  1994    1656     495         50         80         1983
# 11      Yes  2652    1900     484         44         77         1707
# 225     Yes  3596    2466     575         42         78         1944
# 64      Yes  4186    2743     740         48         77         2819
#
#      P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# 16             5     19760        5300    660      1598   93        98
# 163           36     14300        5020    550       950   78        94
# 11            44     17080        4440    400       600   73        91
# 225           46     19964        4328    500       500   94        95
# 64            62     19380        6750    410      1000   90        97
#
#      S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 16         8.4           63   21424        100
# 163       11.1           31   11525         82
# 11         9.9           41   11711         76
# 225       12.1           32   14720         83
# 64         9.8           24   17150         84

# %% [markdown]
# # 3.Print the size of the data set (number of rows and columns)

# %%
# Size function prints the number of elements in data frame, ndim function gives number of dimensions
# shape gives data frame size in row and columns
print("The size of the dataframe: ", dataset.size)
print("The number of columns:", dataset.ndim)
print("The shape of the data frame:", dataset.shape)
# Out:
# The size of the dataframe:  13986
# The number of columns: 2
# The shape of the data frame: (777, 18)

# %% [markdown]
# # 4. List column names from the data frame

# %%
print(dataset.columns)
# Out:
# Index(['Private', 'Apps', 'Accept', 'Enroll', 'Top10perc', 'Top25perc',
#        'F.Undergrad', 'P.Undergrad', 'Outstate', 'Room.Board', 'Books',
#        'Personal', 'PhD', 'Terminal', 'S.F.Ratio', 'perc.alumni', 'Expend',
#        'Grad.Rate'],
#       dtype='object')

# %% [markdown]
# # 5.List data type of each column/feature in data frame

# %%
# using dtypes function with dataframe prints data type of each feature

dataset.dtypes
# Out:
# Private         object
# Apps             int64
# Accept           int64
# Enroll           int64
# Top10perc        int64
# Top25perc        int64
# F.Undergrad      int64
# P.Undergrad      int64
# Outstate         int64
# Room.Board       int64
# Books            int64
# Personal         int64
# PhD              int64
# Terminal         int64
# S.F.Ratio      float64
# perc.alumni      int64
# Expend           int64
# Grad.Rate        int64
# dtype: object

# %% [markdown]
# # 6.Changing the column type with the astype method

# %%
dataset['Accept'] = dataset['Accept'].astype('float64')
print(dataset['Accept'].dtype)
# Out:
# float64

# %%
dataset.dtypes
# Out:
# Private         object
# Apps             int64
# Accept         float64
# Enroll           int64
# Top10perc        int64
# Top25perc        int64
# F.Undergrad      int64
# P.Undergrad      int64
# Outstate         int64
# Room.Board       int64
# Books            int64
# Personal         int64
# PhD              int64
# Terminal         int64
# S.F.Ratio      float64
# perc.alumni      int64
# Expend           int64
# Grad.Rate        int64
# dtype: object

# %% [markdown]
# # 7. Data selection operations in Pandas

# %% [markdown]
# ## 1. Print records of specific columns

# %%
# To print only records of specific columns, following code can be used. It fetches details
# against features namely, Apps and Accept.
# There is a meaning to double [][]: The outer [] tells Pandas that we want to fetch
#columns. whereas, inner [], details name of features against which features are to be fetched

dataset[['Accept','Apps']]
# Out:
#      Accept   Apps
# 0    1232.0   1660
# 1    1924.0   2186
# 2    1097.0   1428
# 3     349.0    417
# 4     146.0    193
# ..      ...    ...
# 772  1515.0   2197
# 773  1805.0   1959
# 774  1915.0   2097
# 775  2453.0  10705
# 776  1855.0   2989
#
# [777 rows x 2 columns]

# %%
dataset[['Top10perc','Top25perc']]
# Out:
#      Top10perc  Top25perc
# 0           23         52
# 1           16         29
# 2           22         50
# 3           60         89
# 4           16         44
# ..         ...        ...
# 772          4         26
# 773         24         47
# 774         34         61
# 775         95         99
# 776         28         63
#
# [777 rows x 2 columns]

# %% [markdown]
# ## 2. Extracting a subset of a pandas dataframe using loc function

# %%
# loc function is used to get subset of data frame,Where user may specify rows and columns
# to be extracted from the dataframe. 

(dataset.loc[0:4,'Apps':'Accept'])

#first five rows against two columns names Apps and Accept will be fetched
# Out:
#    Apps  Accept
# 0  1660  1232.0
# 1  2186  1924.0
# 2  1428  1097.0
# 3   417   349.0
# 4   193   146.0

# %%
(dataset.loc[0:4, :])  
# It fetches 1st 5 rows against all the columns
# Out:
#   Private  Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0     Yes  1660  1232.0     721         23         52         2885
# 1     Yes  2186  1924.0     512         16         29         2683
# 2     Yes  1428  1097.0     336         22         50         1036
# 3     Yes   417   349.0     137         60         89          510
# 4     Yes   193   146.0      55         16         44          249
#
#    P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# 0          537      7440        3300    450      2200   70        78
# 1         1227     12280        6450    750      1500   29        30
# 2           99     11250        3750    400      1165   53        66
# 3           63     12960        5450    450       875   92        97
# 4          869      7560        4120    800      1500   76        72
#
#    S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0       18.1           12    7041         60
# 1       12.2           16   10527         56
# 2       12.9           30    8735         54
# 3        7.7           37   19016         59
# 4       11.9            2   10922         15

# %% [markdown]
# ## 3. Extracting a subset of a pandas dataframe using iloc function

# %%
(dataset.iloc[0:4, 0:2])     ##print 0-4 rows and 0,1 columns

# iloc function is also used to get subset of data frame. However, in this function, indexes
#are entered than row/column names
# Out:
#   Private  Apps
# 0     Yes  1660
# 1     Yes  2186
# 2     Yes  1428
# 3     Yes   417

# %% [markdown]
# ## 4. Filtering specific values in dataframe

# %%
# we can put condition on finding values from the data frame 

(dataset[dataset['Accept']>1000])# print only data samples where Accept value >1000
# Out:
#     Private   Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0       Yes   1660  1232.0     721         23         52         2885
# 1       Yes   2186  1924.0     512         16         29         2683
# 2       Yes   1428  1097.0     336         22         50         1036
# 7       Yes   1899  1720.0     489         37         68         1594
# 10      Yes   1732  1425.0     472         37         75         1830
# ..      ...    ...     ...     ...        ...        ...          ...
# 772      No   2197  1515.0     543          4         26         3089
# 773     Yes   1959  1805.0     695         24         47         2849
# 774     Yes   2097  1915.0     695         34         61         2793
# 775     Yes  10705  2453.0    1317         95         99         5217
# 776     Yes   2989  1855.0     691         28         63         2988
#
#      P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# 0            537      7440        3300    450      2200   70        78
# 1           1227     12280        6450    750      1500   29        30
# 2             99     11250        3750    400      1165   53        66
# 7             32     13868        4826    450       850   89       100
# 10           110     16548        5406    500       600   82        88
# ..           ...       ...         ...    ...       ...  ...       ...
# 772         2029      6797        3900    500      1200   60        60
# 773         1107     11520        4960    600      1250   73        75
# 774          166      6900        4200    617       781   67        75
# 775           83     19840        6510    630      2115   96        96
# 776         1726      4990        3560    500      1250   75        75
#
#      S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0         18.1           12    7041         60
# 1         12.2           16   10527         56
# 2         12.9           30    8735         54
# 7         13.7           37   11487         73
# 10        11.3           31   10932         73
# ..         ...          ...     ...        ...
# 772       21.0           14    4469         40
# 773       13.3           31    9189         83
# 774       14.4           20    8323         49
# 775        5.8           49   40386         99
# 776       18.1           28    4509         99
#
# [429 rows x 18 columns]

# %%
(dataset[dataset['Enroll'] >1000 ])
# Out:
#     Private   Apps   Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 19       No   3540   2001.0    1016         24         54         4190
# 21       No   7313   4664.0    1910         20         63         9940
# 23       No  12809  10308.0    3761         24         49        22593
# 27       No   7548   6791.0    3070         25         57        16262
# 39      Yes   6075   5349.0    2367         34         66         9919
# ..      ...    ...      ...     ...        ...        ...          ...
# 741      No   3224   2519.0    1057         11         31         5000
# 743      No   9167   7191.0    2738         24         53        15739
# 746      No   5548   3563.0    1549         30         71         8909
# 766      No   3325   2047.0    1301         20         45         5800
# 775     Yes  10705   2453.0    1317         95         99         5217
#
#      P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# 19          1512      5130        3592    500      2000   60        62
# 21          1035      6806        2540     96      2000   83        96
# 23          7585      7434        4850    700      2100   88        93
# 27          1716      6300        3933    600      1908   85        91
# 39           484      6450        3920    600      1346   71        76
# ..           ...       ...         ...    ...       ...  ...       ...
# 741          706      6390        2380    110      1622   67        78
# 743         4278      6940        4100    500      1700   80        84
# 746          506      8124        4144    639      2385   83        89
# 766          872      4200        2700    300      1200   53        60
# 775           83     19840        6510    630      2115   96        96
#
#      S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 19        23.1            5    4010         34
# 21        18.3           14    5854         70
# 23        18.9            5    4602         48
# 27        16.7           18    6642         69
# 39        18.5           38    7503         72
# ..         ...          ...     ...        ...
# 741       14.6            9    6554         55
# 743       24.7           11    5983         55
# 746       22.7           10    7203         61
# 766       20.2           18    5318         58
# 775        5.8           49   40386         99
#
# [174 rows x 18 columns]

# %% [markdown]
# ### 5. Iterating in dataframe row by row

# %%
# Using itertuples() method will return an iterator yielding a named tuple for each row in the DataFrame. 
#The first element of the tuple will be the row’s corresponding index value, while the remaining values are the row values

for datavalues in dataset.itertuples():
    print("The datavalues row by row", datavalues)
# Out:
# The datavalues row by row Pandas(Index=0, Private='Yes', Apps=1660, Accept=1232, Enroll=721, Top10perc=23, Top25perc=52, _7=2885, _8=537, Outstate=7440, _10=3300, Books=450, Personal=2200, PhD=70, Terminal=78, _15=18.1, _16=12, Expend=7041, _18=60)
# The datavalues row by row Pandas(Index=1, Private='Yes', Apps=2186, Accept=1924, Enroll=512, Top10perc=16, Top25perc=29, _7=2683, _8=1227, Outstate=12280, _10=6450, Books=750, Personal=1500, PhD=29, Terminal=30, _15=12.2, _16=16, Expend=10527, _18=56)
# The datavalues row by row Pandas(Index=2, Private='Yes', Apps=1428, Accept=1097, Enroll=336, Top10perc=22, Top25perc=50, _7=1036, _8=99, Outstate=11250, _10=3750, Books=400, Personal=1165, PhD=53, Terminal=66, _15=12.9, _16=30, Expend=8735, _18=54)
# The datavalues row by row Pandas(Index=3, Private='Yes', Apps=417, Accept=349, Enroll=137, Top10perc=60, Top25perc=89, _7=510, _8=63, Outstate=12960, _10=5450, Books=450, Personal=875, PhD=92, Terminal=97, _15=7.7, _16=37, Expend=19016, _18=59)
# The datavalues row by row Pandas(Index=4, Private='Yes', Apps=193, Accept=146, Enroll=55, Top10perc=16, Top25perc=44, _7=249, _8=869, Outstate=7560, _10=4120, Books=800, Personal=1500, PhD=76, Terminal=72, _15=11.9, _16=2, Expend=10922, _18=15)
# The datavalues row by row Pandas(Index=5, Private='Yes', Apps=587, Accept=479, Enroll=158, Top10perc=38, Top25perc=62, _7=678, _8=41, Outstate=13500, _10=3335, Books=500, Personal=675, PhD=67, Terminal=73, _15=9.4, _16=11, Expend=9727, _18=55)
# The datavalues row by row Pandas(Index=6, Private='Yes', Apps=353, Accept=340, Enroll=103, Top10perc=17, Top25perc=45, _7=416, _8=230, Outstate=13290, _10=5720, Books=500, Personal=1500, PhD=90, Terminal=93, _15=11.5, _16=26, Expend=8861, _18=63)
# The datavalues row by row Pandas(Index=7, Private='Yes', Apps=1899, Accept=1720, Enroll=489, Top10perc=37, Top25perc=68, _7=1594, _8=32, Outstate=13868, _10=4826, Books=450, Personal=850, PhD=89, Terminal=100, _15=13.7, _16=37, Expend=11487, _18=73)
# The datavalues row by row Pandas(Index=8, Private='Yes', Apps=1038, Accept=839, Enroll=227, Top10perc=30, Top25perc=63, _7=973, _8=306, Outstate=15595, _10=4400, Books=300, Personal=500, PhD=79, Terminal=84, _15=11.3, _16=23, Expend=11644, _18=80)
# The datavalues row by row Pandas(Index=9, Private='Yes', Apps=582, Accept=498, Enroll=172, Top10perc=21, Top25perc=44, _7=799, _8=78, Outstate=10468, _10=3380, Books=660, Personal=1800, PhD=40, Terminal=41, _15=11.5, _16=15, Expend=8991, _18=52)
# The datavalues row by row Pandas(Index=10, Private='Yes', Apps=1732, Accept=1425, Enroll=472, Top10perc=37, Top25perc=75, _7=1830, _8=110, Outstate=16548, _10=5406, Books=500, Personal=600, PhD=82, Terminal=88, _15=11.3, _16=31, Expend=10932, _18=73)
# The datavalues row by row Pandas(Index=11, Private='Yes', Apps=2652, Accept=1900, Enroll=484, Top10perc=44, Top25perc=77, _7=1707, _8=44, Outstate=17080, _10=4440, Books=400, Personal=600, PhD=73, Terminal=91, _15=9.9, _16=41, Expend=11711, _18=76)
# The datavalues row by row Pandas(Index=12, Private='Yes', Apps=1179, Accept=780, Enroll=290, Top10perc=38, Top25perc=64, _7=1130, _8=638, Outstate=9690, _10=4785, Books=600, Personal=1000, PhD=60, Terminal=84, _15=13.3, _16=21, Expend=7940, _18=74)
# The datavalues row by row Pandas(Index=13, Private='Yes', Apps=1267, Accept=1080, Enroll=385, Top10perc=44, Top25perc=73, _7=1306, _8=28, Outstate=12572, _10=4552, Books=400, Personal=400, PhD=79, Terminal=87, _15=15.3, _16=32, Expend=9305, _18=68)
# The datavalues row by row Pandas(Index=14, Private='Yes', Apps=494, Accept=313, Enroll=157, Top10perc=23, Top25perc=46, _7=1317, _8=1235, Outstate=8352, _10=3640, Books=650, Personal=2449, PhD=36, Terminal=69, _15=11.1, _16=26, Expend=8127, _18=55)
# The datavalues row by row Pandas(Index=15, Private='Yes', Apps=1420, Accept=1093, Enroll=220, Top10perc=9, Top25perc=22, _7=1018, _8=287, Outstate=8700, _10=4780, Books=450, Personal=1400, PhD=78, Terminal=84, _15=14.7, _16=19, Expend=7355, _18=69)
# The datavalues row by row Pandas(Index=16, Private='Yes', Apps=4302, Accept=992, Enroll=418, Top10perc=83, Top25perc=96, _7=1593, _8=5, Outstate=19760, _10=5300, Books=660, Personal=1598, PhD=93, Terminal=98, _15=8.4, _16=63, Expend=21424, _18=100)
# The datavalues row by row Pandas(Index=17, Private='Yes', Apps=1216, Accept=908, Enroll=423, Top10perc=19, Top25perc=40, _7=1819, _8=281, Outstate=10100, _10=3520, Books=550, Personal=1100, PhD=48, Terminal=61, _15=12.1, _16=14, Expend=7994, _18=59)
# The datavalues row by row Pandas(Index=18, Private='Yes', Apps=1130, Accept=704, Enroll=322, Top10perc=14, Top25perc=23, _7=1586, _8=326, Outstate=9996, _10=3090, Books=900, Personal=1320, PhD=62, Terminal=66, _15=11.5, _16=18, Expend=10908, _18=46)
# The datavalues row by row Pandas(Index=19, Private='No', Apps=3540, Accept=2001, Enroll=1016, Top10perc=24, Top25perc=54, _7=4190, _8=1512, Outstate=5130, _10=3592, Books=500, Personal=2000, PhD=60, Terminal=62, _15=23.1, _16=5, Expend=4010, _18=34)
# The datavalues row by row Pandas(Index=20, Private='Yes', Apps=713, Accept=661, Enroll=252, Top10perc=25, Top25perc=44, _7=712, _8=23, Outstate=15476, _10=3336, Books=400, Personal=1100, PhD=69, Terminal=82, _15=11.3, _16=35, Expend=42926, _18=48)
# The datavalues row by row Pandas(Index=21, Private='No', Apps=7313, Accept=4664, Enroll=1910, Top10perc=20, Top25perc=63, _7=9940, _8=1035, Outstate=6806, _10=2540, Books=96, Personal=2000, PhD=83, Terminal=96, _15=18.3, _16=14, Expend=5854, _18=70)
# The datavalues row by row Pandas(Index=22, Private='Yes', Apps=619, Accept=516, Enroll=219, Top10perc=20, Top25perc=51, _7=1251, _8=767, Outstate=11208, _10=4124, Books=350, Personal=1615, PhD=55, Terminal=65, _15=12.7, _16=25, Expend=6584, _18=65)
# The datavalues row by row Pandas(Index=23, Private='No', Apps=12809, Accept=10308, Enroll=3761, Top10perc=24, Top25perc=49, _7=22593, _8=7585, Outstate=7434, _10=4850, Books=700, Personal=2100, PhD=88, Terminal=93, _15=18.9, _16=5, Expend=4602, _18=48)
# The datavalues row by row Pandas(Index=24, Private='Yes', Apps=708, Accept=334, Enroll=166, Top10perc=46, Top25perc=74, _7=530, _8=182, Outstate=8644, _10=3922, Books=500, Personal=800, PhD=79, Terminal=88, _15=12.6, _16=24, Expend=14579, _18=54)
# The datavalues row by row Pandas(Index=25, Private='No', Apps=1734, Accept=1729, Enroll=951, Top10perc=12, Top25perc=52, _7=3602, _8=939, Outstate=3460, _10=2650, Books=450, Personal=1000, PhD=57, Terminal=60, _15=19.6, _16=5, Expend=4739, _18=48)
# The datavalues row by row Pandas(Index=26, Private='Yes', Apps=2135, Accept=1700, Enroll=491, Top10perc=23, Top25perc=59, _7=1708, _8=689, Outstate=12000, _10=5920, Books=500, Personal=500, PhD=93, Terminal=93, _15=13.8, _16=30, Expend=7100, _18=88)
# The datavalues row by row Pandas(Index=27, Private='No', Apps=7548, Accept=6791, Enroll=3070, Top10perc=25, Top25perc=57, _7=16262, _8=1716, Outstate=6300, _10=3933, Books=600, Personal=1908, PhD=85, Terminal=91, _15=16.7, _16=18, Expend=6642, _18=69)
# The datavalues row by row Pandas(Index=28, Private='Yes', Apps=662, Accept=513, Enroll=257, Top10perc=12, Top25perc=30, _7=2074, _8=726, Outstate=11902, _10=4372, Books=540, Personal=950, PhD=65, Terminal=65, _15=12.8, _16=31, Expend=7836, _18=58)
# The datavalues row by row Pandas(Index=29, Private='Yes', Apps=1879, Accept=1658, Enroll=497, Top10perc=36, Top25perc=69, _7=1950, _8=38, Outstate=13353, _10=4173, Books=540, Personal=821, PhD=78, Terminal=83, _15=12.7, _16=40, Expend=9220, _18=71)
# The datavalues row by row Pandas(Index=30, Private='Yes', Apps=761, Accept=725, Enroll=306, Top10perc=21, Top25perc=58, _7=1337, _8=300, Outstate=10990, _10=3244, Books=600, Personal=1021, PhD=66, Terminal=70, _15=10.4, _16=30, Expend=6871, _18=69)
# The datavalues row by row Pandas(Index=31, Private='Yes', Apps=948, Accept=798, Enroll=295, Top10perc=42, Top25perc=74, _7=1120, _8=15, Outstate=11280, _10=4342, Books=400, Personal=1150, PhD=81, Terminal=95, _15=13.0, _16=33, Expend=11361, _18=71)
# The datavalues row by row Pandas(Index=32, Private='Yes', Apps=627, Accept=556, Enroll=172, Top10perc=16, Top25perc=40, _7=777, _8=538, Outstate=9925, _10=4135, Books=750, Personal=1350, PhD=59, Terminal=67, _15=22.4, _16=11, Expend=6523, _18=48)
# The datavalues row by row Pandas(Index=33, Private='Yes', Apps=602, Accept=483, Enroll=206, Top10perc=21, Top25perc=47, _7=958, _8=466, Outstate=8620, _10=4100, Books=400, Personal=2250, PhD=58, Terminal=68, _15=11.0, _16=21, Expend=6136, _18=65)
# The datavalues row by row Pandas(Index=34, Private='Yes', Apps=1690, Accept=1366, Enroll=662, Top10perc=30, Top25perc=61, _7=2718, _8=1460, Outstate=10995, _10=4410, Books=1000, Personal=1000, PhD=68, Terminal=74, _15=17.6, _16=20, Expend=8086, _18=85)
# The datavalues row by row Pandas(Index=35, Private='Yes', Apps=261, Accept=192, Enroll=111, Top10perc=15, Top25perc=36, _7=453, _8=266, Outstate=9690, _10=4300, Books=500, Personal=500, PhD=57, Terminal=77, _15=9.7, _16=35, Expend=9337, _18=71)
# The datavalues row by row Pandas(Index=36, Private='Yes', Apps=1910, Accept=838, Enroll=285, Top10perc=50, Top25perc=85, _7=1004, _8=15, Outstate=19264, _10=6206, Books=750, Personal=750, PhD=98, Terminal=98, _15=10.4, _16=30, Expend=13894, _18=79)
# The datavalues row by row Pandas(Index=37, Private='Yes', Apps=2496, Accept=1402, Enroll=531, Top10perc=53, Top25perc=95, _7=2121, _8=69, Outstate=17926, _10=8124, Books=600, Personal=850, PhD=83, Terminal=93, _15=10.3, _16=33, Expend=12580, _18=91)
# The datavalues row by row Pandas(Index=38, Private='Yes', Apps=990, Accept=784, Enroll=279, Top10perc=18, Top25perc=45, _7=1811, _8=3144, Outstate=11290, _10=5360, Books=600, Personal=1800, PhD=76, Terminal=78, _15=12.6, _16=11, Expend=9084, _18=72)
# The datavalues row by row Pandas(Index=39, Private='Yes', Apps=6075, Accept=5349, Enroll=2367, Top10perc=34, Top25perc=66, _7=9919, _8=484, Outstate=6450, _10=3920, Books=600, Personal=1346, PhD=71, Terminal=76, _15=18.5, _16=38, Expend=7503, _18=72)
# The datavalues row by row Pandas(Index=40, Private='Yes', Apps=1163, Accept=850, Enroll=348, Top10perc=23, Top25perc=56, _7=878, _8=519, Outstate=12850, _10=5400, Books=400, Personal=800, PhD=78, Terminal=89, _15=12.2, _16=30, Expend=8954, _18=73)
# The datavalues row by row Pandas(Index=41, Private='Yes', Apps=807, Accept=707, Enroll=308, Top10perc=39, Top25perc=63, _7=1198, _8=605, Outstate=8840, _10=2950, Books=750, Personal=1290, PhD=74, Terminal=82, _15=13.1, _16=31, Expend=6668, _18=84)
# The datavalues row by row Pandas(Index=42, Private='Yes', Apps=632, Accept=494, Enroll=129, Top10perc=17, Top25perc=36, _7=709, _8=131, Outstate=9000, _10=4850, Books=300, Personal=2480, PhD=78, Terminal=85, _15=13.2, _16=10, Expend=7550, _18=52)
# The datavalues row by row Pandas(Index=43, Private='Yes', Apps=1220, Accept=974, Enroll=481, Top10perc=28, Top25perc=67, _7=1964, _8=623, Outstate=7800, _10=3664, Books=650, Personal=900, PhD=61, Terminal=61, _15=11.1, _16=19, Expend=7614, _18=49)
# The datavalues row by row Pandas(Index=44, Private='Yes', Apps=1320, Accept=923, Enroll=284, Top10perc=26, Top25perc=54, _7=1085, _8=81, Outstate=16304, _10=3616, Books=355, Personal=715, PhD=87, Terminal=95, _15=11.1, _16=26, Expend=12957, _18=69)
# The datavalues row by row Pandas(Index=45, Private='No', Apps=1208, Accept=877, Enroll=546, Top10perc=12, Top25perc=36, _7=3796, _8=824, Outstate=4425, _10=2700, Books=660, Personal=1800, PhD=57, Terminal=62, _15=19.6, _16=16, Expend=3752, _18=46)
# The datavalues row by row Pandas(Index=46, Private='Yes', Apps=632, Accept=620, Enroll=222, Top10perc=14, Top25perc=24, _7=702, _8=501, Outstate=9550, _10=3850, Books=350, Personal=250, PhD=64, Terminal=84, _15=14.1, _16=18, Expend=5922, _18=58)
# The datavalues row by row Pandas(Index=47, Private='Yes', Apps=519, Accept=327, Enroll=114, Top10perc=25, Top25perc=53, _7=457, _8=2, Outstate=21700, _10=4100, Books=600, Personal=500, PhD=35, Terminal=59, _15=10.1, _16=33, Expend=16364, _18=55)
# The datavalues row by row Pandas(Index=48, Private='Yes', Apps=3466, Accept=2330, Enroll=640, Top10perc=20, Top25perc=60, _7=3095, _8=1533, Outstate=13800, _10=5510, Books=630, Personal=850, PhD=87, Terminal=87, _15=17.5, _16=20, Expend=10941, _18=82)
# The datavalues row by row Pandas(Index=49, Private='Yes', Apps=1858, Accept=1221, Enroll=480, Top10perc=37, Top25perc=68, _7=1620, _8=49, Outstate=8050, _10=3940, Books=350, Personal=2375, PhD=80, Terminal=80, _15=16.3, _16=17, Expend=10511, _18=63)
# The datavalues row by row Pandas(Index=50, Private='Yes', Apps=878, Accept=816, Enroll=200, Top10perc=16, Top25perc=41, _7=706, _8=62, Outstate=8740, _10=3363, Books=550, Personal=1700, PhD=62, Terminal=68, _15=11.6, _16=29, Expend=7718, _18=48)
# The datavalues row by row Pandas(Index=51, Private='Yes', Apps=202, Accept=184, Enroll=122, Top10perc=19, Top25perc=42, _7=537, _8=101, Outstate=8540, _10=3580, Books=500, Personal=1400, PhD=61, Terminal=80, _15=8.8, _16=32, Expend=8324, _18=56)
# The datavalues row by row Pandas(Index=52, Private='Yes', Apps=502, Accept=384, Enroll=104, Top10perc=11, Top25perc=28, _7=347, _8=74, Outstate=6200, _10=2900, Books=600, Personal=800, PhD=63, Terminal=63, _15=11.7, _16=13, Expend=7623, _18=35)
# The datavalues row by row Pandas(Index=53, Private='Yes', Apps=1646, Accept=1150, Enroll=542, Top10perc=12, Top25perc=30, _7=2128, _8=82, Outstate=5188, _10=3396, Books=650, Personal=2500, PhD=48, Terminal=48, _15=13.8, _16=9, Expend=6817, _18=58)
# The datavalues row by row Pandas(Index=54, Private='Yes', Apps=805, Accept=588, Enroll=287, Top10perc=67, Top25perc=88, _7=1376, _8=207, Outstate=11660, _10=4325, Books=400, Personal=900, PhD=74, Terminal=79, _15=14.0, _16=34, Expend=8649, _18=72)
# The datavalues row by row Pandas(Index=55, Private='Yes', Apps=500, Accept=336, Enroll=156, Top10perc=25, Top25perc=55, _7=421, _8=27, Outstate=6500, _10=2700, Books=500, Personal=1000, PhD=76, Terminal=76, _15=14.3, _16=53, Expend=8377, _18=51)
# The datavalues row by row Pandas(Index=56, Private='No', Apps=6773, Accept=3028, Enroll=1025, Top10perc=15, Top25perc=55, _7=5847, _8=946, Outstate=7844, _10=2948, Books=500, Personal=1680, PhD=66, Terminal=68, _15=18.0, _16=19, Expend=7041, _18=75)
# The datavalues row by row Pandas(Index=57, Private='Yes', Apps=377, Accept=358, Enroll=181, Top10perc=15, Top25perc=30, _7=653, _8=129, Outstate=7150, _10=4350, Books=450, Personal=1500, PhD=61, Terminal=67, _15=17.8, _16=3, Expend=6259, _18=53)
# The datavalues row by row Pandas(Index=58, Private='Yes', Apps=692, Accept=514, Enroll=209, Top10perc=20, Top25perc=50, _7=760, _8=81, Outstate=9900, _10=3990, Books=400, Personal=900, PhD=76, Terminal=71, _15=13.3, _16=19, Expend=9073, _18=58)
# The datavalues row by row Pandas(Index=59, Private='Yes', Apps=20192, Accept=13007, Enroll=3810, Top10perc=45, Top25perc=80, _7=14971, _8=3113, Outstate=18420, _10=6810, Books=475, Personal=1025, PhD=80, Terminal=81, _15=11.9, _16=16, Expend=16836, _18=72)
# The datavalues row by row Pandas(Index=60, Private='Yes', Apps=3356, Accept=1019, Enroll=418, Top10perc=76, Top25perc=100, _7=1490, _8=8, Outstate=19030, _10=5885, Books=1495, Personal=875, PhD=93, Terminal=96, _15=11.2, _16=52, Expend=20447, _18=96)
# The datavalues row by row Pandas(Index=61, Private='No', Apps=9251, Accept=7333, Enroll=3076, Top10perc=14, Top25perc=45, _7=13699, _8=1213, Outstate=7452, _10=3352, Books=600, Personal=1700, PhD=81, Terminal=89, _15=21.1, _16=14, Expend=6918, _18=67)
# The datavalues row by row Pandas(Index=62, Private='Yes', Apps=443, Accept=330, Enroll=151, Top10perc=5, Top25perc=36, _7=453, _8=42, Outstate=14080, _10=6270, Books=500, Personal=900, PhD=57, Terminal=80, _15=10.2, _16=21, Expend=15387, _18=46)
# The datavalues row by row Pandas(Index=63, Private='Yes', Apps=3767, Accept=3414, Enroll=1061, Top10perc=30, Top25perc=58, _7=4531, _8=643, Outstate=10870, _10=4440, Books=2000, Personal=1522, PhD=75, Terminal=81, _15=14.4, _16=21, Expend=7671, _18=85)
# The datavalues row by row Pandas(Index=64, Private='Yes', Apps=4186, Accept=2743, Enroll=740, Top10perc=48, Top25perc=77, _7=2819, _8=62, Outstate=19380, _10=6750, Books=410, Personal=1000, PhD=90, Terminal=97, _15=9.8, _16=24, Expend=17150, _18=84)
# The datavalues row by row Pandas(Index=65, Private='Yes', Apps=367, Accept=274, Enroll=158, Top10perc=12, Top25perc=41, _7=917, _8=479, Outstate=9592, _10=5879, Books=500, Personal=700, PhD=71, Terminal=80, _15=13.7, _16=12, Expend=5935, _18=49)
# The datavalues row by row Pandas(Index=66, Private='Yes', Apps=1436, Accept=1228, Enroll=1202, Top10perc=10, Top25perc=26, _7=1320, _8=822, Outstate=4371, _10=2370, Books=500, Personal=2000, PhD=62, Terminal=62, _15=12.6, _16=10, Expend=4900, _18=18)
# The datavalues row by row Pandas(Index=67, Private='Yes', Apps=392, Accept=351, Enroll=155, Top10perc=16, Top25perc=44, _7=738, _8=430, Outstate=10260, _10=3597, Books=600, Personal=1500, PhD=39, Terminal=66, _15=13.1, _16=26, Expend=8355, _18=58)
# The datavalues row by row Pandas(Index=68, Private='Yes', Apps=838, Accept=673, Enroll=292, Top10perc=22, Top25perc=53, _7=881, _8=55, Outstate=10265, _10=4725, Books=560, Personal=875, PhD=68, Terminal=73, _15=13.2, _16=24, Expend=8655, _18=82)
# The datavalues row by row Pandas(Index=69, Private='Yes', Apps=7365, Accept=5402, Enroll=4615, Top10perc=48, Top25perc=82, _7=27378, _8=1253, Outstate=2340, _10=3580, Books=860, Personal=1220, PhD=76, Terminal=76, _15=20.5, _16=40, Expend=7916, _18=33)
# The datavalues row by row Pandas(Index=70, Private='Yes', Apps=12586, Accept=3239, Enroll=1462, Top10perc=87, Top25perc=95, _7=5643, _8=349, Outstate=19528, _10=5926, Books=720, Personal=1100, PhD=99, Terminal=100, _15=7.6, _16=39, Expend=20440, _18=97)
# The datavalues row by row Pandas(Index=71, Private='Yes', Apps=1465, Accept=810, Enroll=313, Top10perc=71, Top25perc=95, _7=1088, _8=16, Outstate=18165, _10=6750, Books=500, Personal=1200, PhD=100, Terminal=100, _15=12.3, _16=49, Expend=17449, _18=89)
# The datavalues row by row Pandas(Index=72, Private='Yes', Apps=6548, Accept=3813, Enroll=862, Top10perc=49, Top25perc=85, _7=3316, _8=31, Outstate=18550, _10=4750, Books=800, Personal=1200, PhD=95, Terminal=97, _15=14.2, _16=36, Expend=13675, _18=93)
# The datavalues row by row Pandas(Index=73, Private='Yes', Apps=860, Accept=688, Enroll=285, Top10perc=32, Top25perc=70, _7=1928, _8=442, Outstate=13306, _10=3797, Books=450, Personal=950, PhD=62, Terminal=69, _15=8.8, _16=10, Expend=6333, _18=78)
# The datavalues row by row Pandas(Index=74, Private='Yes', Apps=2362, Accept=2037, Enroll=700, Top10perc=40, Top25perc=68, _7=2607, _8=148, Outstate=13130, _10=4650, Books=500, Personal=1600, PhD=77, Terminal=81, _15=10.9, _16=29, Expend=9511, _18=83)
# The datavalues row by row Pandas(Index=75, Private='Yes', Apps=599, Accept=494, Enroll=224, Top10perc=8, Top25perc=28, _7=1035, _8=446, Outstate=10518, _10=6250, Books=300, Personal=300, PhD=59, Terminal=76, _15=16.5, _16=36, Expend=7117, _18=71)
# The datavalues row by row Pandas(Index=76, Private='Yes', Apps=1011, Accept=604, Enroll=213, Top10perc=17, Top25perc=42, _7=693, _8=868, Outstate=8900, _10=4600, Books=425, Personal=1000, PhD=87, Terminal=96, _15=13.9, _16=25, Expend=7922, _18=55)
# The datavalues row by row Pandas(Index=77, Private='Yes', Apps=563, Accept=247, Enroll=247, Top10perc=23, Top25perc=52, _7=1427, _8=432, Outstate=12950, _10=5300, Books=612, Personal=576, PhD=72, Terminal=74, _15=12.4, _16=17, Expend=8985, _18=60)
# The datavalues row by row Pandas(Index=78, Private='No', Apps=7811, Accept=3817, Enroll=1650, Top10perc=47, Top25perc=73, _7=12911, _8=1404, Outstate=7380, _10=4877, Books=612, Personal=2091, PhD=72, Terminal=81, _15=19.8, _16=13, Expend=8453, _18=59)
# The datavalues row by row Pandas(Index=79, Private='No', Apps=4540, Accept=3294, Enroll=1483, Top10perc=5, Top25perc=60, _7=13494, _8=1254, Outstate=7706, _10=4368, Books=600, Personal=1926, PhD=90, Terminal=90, _15=21.2, _16=8, Expend=7268, _18=61)
# The datavalues row by row Pandas(Index=80, Private='Yes', Apps=1784, Accept=1512, Enroll=913, Top10perc=29, Top25perc=56, _7=3401, _8=136, Outstate=10230, _10=3710, Books=400, Personal=1210, PhD=75, Terminal=81, _15=14.8, _16=41, Expend=7786, _18=81)
# The datavalues row by row Pandas(Index=81, Private='Yes', Apps=2087, Accept=1339, Enroll=657, Top10perc=20, Top25perc=54, _7=3191, _8=1204, Outstate=7550, _10=2790, Books=600, Personal=500, PhD=77, Terminal=77, _15=21.8, _16=34, Expend=3739, _18=63)
# The datavalues row by row Pandas(Index=82, Private='Yes', Apps=848, Accept=587, Enroll=298, Top10perc=25, Top25perc=55, _7=935, _8=184, Outstate=6060, _10=3070, Books=600, Personal=1300, PhD=62, Terminal=66, _15=17.7, _16=13, Expend=5391, _18=49)
# The datavalues row by row Pandas(Index=83, Private='Yes', Apps=2853, Accept=2193, Enroll=753, Top10perc=16, Top25perc=34, _7=2978, _8=434, Outstate=10750, _10=5340, Books=400, Personal=1130, PhD=90, Terminal=92, _15=14.6, _16=26, Expend=7972, _18=64)
# The datavalues row by row Pandas(Index=84, Private='Yes', Apps=1747, Accept=1382, Enroll=449, Top10perc=34, Top25perc=66, _7=1662, _8=960, Outstate=13050, _10=4000, Books=500, Personal=800, PhD=64, Terminal=69, _15=12.1, _16=27, Expend=9557, _18=83)
# The datavalues row by row Pandas(Index=85, Private='Yes', Apps=100, Accept=90, Enroll=35, Top10perc=10, Top25perc=52, _7=282, _8=331, Outstate=8400, _10=2812, Books=300, Personal=2134, PhD=10, Terminal=50, _15=12.1, _16=24, Expend=7976, _18=52)
# The datavalues row by row Pandas(Index=86, Private='Yes', Apps=2694, Accept=1579, Enroll=489, Top10perc=75, Top25perc=93, _7=1870, _8=12, Outstate=19292, _10=3957, Books=550, Personal=550, PhD=81, Terminal=93, _15=10.4, _16=60, Expend=17960, _18=91)
# The datavalues row by row Pandas(Index=87, Private='Yes', Apps=8728, Accept=5201, Enroll=1191, Top10perc=60, Top25perc=89, _7=4265, _8=291, Outstate=17900, _10=5690, Books=450, Personal=1250, PhD=86, Terminal=93, _15=9.2, _16=31, Expend=24386, _18=74)
# The datavalues row by row Pandas(Index=88, Private='Yes', Apps=1160, Accept=991, Enroll=352, Top10perc=19, Top25perc=55, _7=1357, _8=737, Outstate=12200, _10=3880, Books=480, Personal=930, PhD=74, Terminal=81, _15=17.8, _16=25, Expend=7666, _18=79)
# The datavalues row by row Pandas(Index=89, Private='Yes', Apps=1096, Accept=951, Enroll=464, Top10perc=27, Top25perc=62, _7=1776, _8=239, Outstate=8150, _10=3150, Books=400, Personal=500, PhD=61, Terminal=62, _15=13.6, _16=16, Expend=6716, _18=67)
# The datavalues row by row Pandas(Index=90, Private='Yes', Apps=1616, Accept=1427, Enroll=434, Top10perc=20, Top25perc=43, _7=1405, _8=580, Outstate=13125, _10=3775, Books=500, Personal=1300, PhD=74, Terminal=89, _15=15.9, _16=22, Expend=7364, _18=62)
# The datavalues row by row Pandas(Index=91, Private='Yes', Apps=3877, Accept=3156, Enroll=713, Top10perc=71, Top25perc=93, _7=3051, _8=513, Outstate=15700, _10=4730, Books=525, Personal=1460, PhD=95, Terminal=95, _15=2.9, _16=29, Expend=19733, _18=67)
# The datavalues row by row Pandas(Index=92, Private='No', Apps=1257, Accept=940, Enroll=363, Top10perc=9, Top25perc=22, _7=1547, _8=294, Outstate=7656, _10=4690, Books=400, Personal=700, PhD=89, Terminal=91, _15=14.7, _16=8, Expend=6318, _18=79)
# The datavalues row by row Pandas(Index=93, Private='Yes', Apps=1083, Accept=880, Enroll=291, Top10perc=13, Top25perc=34, _7=915, _8=80, Outstate=9270, _10=4100, Books=600, Personal=1860, PhD=75, Terminal=82, _15=13.5, _16=27, Expend=8425, _18=55)
# The datavalues row by row Pandas(Index=94, Private='Yes', Apps=1754, Accept=1465, Enroll=505, Top10perc=24, Top25perc=49, _7=2159, _8=211, Outstate=13712, _10=6408, Books=526, Personal=1100, PhD=90, Terminal=96, _15=9.3, _16=18, Expend=12751, _18=75)
# The datavalues row by row Pandas(Index=95, Private='Yes', Apps=3847, Accept=3433, Enroll=527, Top10perc=9, Top25perc=35, _7=1010, _8=12, Outstate=9384, _10=4840, Books=600, Personal=500, PhD=22, Terminal=47, _15=14.3, _16=20, Expend=7697, _18=118)
# The datavalues row by row Pandas(Index=96, Private='Yes', Apps=776, Accept=607, Enroll=198, Top10perc=25, Top25perc=58, _7=791, _8=764, Outstate=14340, _10=5285, Books=500, Personal=1000, PhD=58, Terminal=83, _15=11.7, _16=39, Expend=10961, _18=74)
# The datavalues row by row Pandas(Index=97, Private='Yes', Apps=1307, Accept=1090, Enroll=616, Top10perc=25, Top25perc=55, _7=2196, _8=82, Outstate=7344, _10=4410, Books=570, Personal=1000, PhD=50, Terminal=52, _15=15.3, _16=34, Expend=6897, _18=64)
# The datavalues row by row Pandas(Index=98, Private='Yes', Apps=369, Accept=312, Enroll=90, Top10perc=12, Top25perc=46, _7=396, _8=526, Outstate=11400, _10=5400, Books=500, Personal=760, PhD=41, Terminal=85, _15=9.5, _16=20, Expend=9583, _18=24)
# The datavalues row by row Pandas(Index=99, Private='Yes', Apps=495, Accept=434, Enroll=210, Top10perc=35, Top25perc=55, _7=775, _8=44, Outstate=8950, _10=3490, Books=600, Personal=1900, PhD=86, Terminal=92, _15=11.3, _16=25, Expend=9685, _18=66)
# The datavalues row by row Pandas(Index=100, Private='Yes', Apps=601, Accept=396, Enroll=203, Top10perc=1, Top25perc=20, _7=525, _8=323, Outstate=11230, _10=6643, Books=2340, Personal=620, PhD=8, Terminal=58, _15=6.8, _16=4, Expend=13025, _18=47)
# The datavalues row by row Pandas(Index=101, Private='Yes', Apps=1283, Accept=1113, Enroll=401, Top10perc=31, Top25perc=65, _7=1355, _8=40, Outstate=10938, _10=3660, Books=650, Personal=600, PhD=76, Terminal=90, _15=13.5, _16=29, Expend=8444, _18=67)
# The datavalues row by row Pandas(Index=102, Private='No', Apps=4158, Accept=2532, Enroll=902, Top10perc=6, Top25perc=24, _7=6394, _8=3881, Outstate=5962, _10=4444, Books=500, Personal=985, PhD=69, Terminal=73, _15=16.7, _16=4, Expend=4900, _18=49)
# The datavalues row by row Pandas(Index=103, Private='No', Apps=4681, Accept=4101, Enroll=1436, Top10perc=10, Top25perc=35, _7=8094, _8=1596, Outstate=4620, _10=3288, Books=300, Personal=2250, PhD=69, Terminal=80, _15=19.7, _16=4, Expend=5501, _18=50)
# The datavalues row by row Pandas(Index=104, Private='No', Apps=2785, Accept=2011, Enroll=1007, Top10perc=8, Top25perc=65, _7=6507, _8=898, Outstate=7242, _10=3603, Books=654, Personal=1416, PhD=67, Terminal=89, _15=18.1, _16=0, Expend=6413, _18=51)
# The datavalues row by row Pandas(Index=105, Private='Yes', Apps=174, Accept=146, Enroll=88, Top10perc=8, Top25perc=29, _7=1047, _8=33, Outstate=8300, _10=3080, Books=600, Personal=600, PhD=62, Terminal=62, _15=15.2, _16=18, Expend=3365, _18=58)
# The datavalues row by row Pandas(Index=106, Private='Yes', Apps=1013, Accept=888, Enroll=288, Top10perc=55, Top25perc=82, _7=943, _8=7, Outstate=11850, _10=4270, Books=600, Personal=900, PhD=95, Terminal=99, _15=11.4, _16=60, Expend=13118, _18=74)
# The datavalues row by row Pandas(Index=107, Private='Yes', Apps=959, Accept=771, Enroll=351, Top10perc=23, Top25perc=48, _7=1662, _8=209, Outstate=16624, _10=5895, Books=600, Personal=1100, PhD=72, Terminal=80, _15=12.8, _16=6, Expend=12692, _18=47)
# The datavalues row by row Pandas(Index=108, Private='Yes', Apps=212, Accept=197, Enroll=91, Top10perc=28, Top25perc=56, _7=471, _8=148, Outstate=13500, _10=5230, Books=400, Personal=850, PhD=95, Terminal=98, _15=9.3, _16=37, Expend=16095, _18=52)
# The datavalues row by row Pandas(Index=109, Private='Yes', Apps=342, Accept=254, Enroll=126, Top10perc=25, Top25perc=64, _7=518, _8=232, Outstate=10335, _10=5015, Books=700, Personal=850, PhD=71, Terminal=71, _15=8.3, _16=29, Expend=7729, _18=73)
# The datavalues row by row Pandas(Index=110, Private='Yes', Apps=81, Accept=72, Enroll=51, Top10perc=33, Top25perc=71, _7=139, _8=3, Outstate=8730, _10=3600, Books=400, Personal=800, PhD=92, Terminal=92, _15=9.3, _16=17, Expend=10922, _18=58)
# The datavalues row by row Pandas(Index=111, Private='Yes', Apps=880, Accept=520, Enroll=224, Top10perc=16, Top25perc=42, _7=1068, _8=364, Outstate=9300, _10=3260, Books=600, Personal=900, PhD=81, Terminal=81, _15=11.1, _16=24, Expend=8129, _18=63)
# The datavalues row by row Pandas(Index=112, Private='No', Apps=883, Accept=766, Enroll=428, Top10perc=3, Top25perc=37, _7=2910, _8=1749, Outstate=7860, _10=4750, Books=525, Personal=1889, PhD=80, Terminal=82, _15=21.2, _16=16, Expend=4639, _18=48)
# The datavalues row by row Pandas(Index=113, Private='Yes', Apps=1196, Accept=697, Enroll=499, Top10perc=21, Top25perc=47, _7=959, _8=13, Outstate=4412, _10=2460, Books=500, Personal=1000, PhD=69, Terminal=69, _15=16.9, _16=31, Expend=7083, _18=21)
# The datavalues row by row Pandas(Index=114, Private='Yes', Apps=1860, Accept=767, Enroll=227, Top10perc=71, Top25perc=93, _7=887, _8=1, Outstate=17000, _10=6010, Books=500, Personal=850, PhD=99, Terminal=99, _15=9.6, _16=52, Expend=18443, _18=87)
# The datavalues row by row Pandas(Index=115, Private='Yes', Apps=2887, Accept=2059, Enroll=457, Top10perc=30, Top25perc=61, _7=1928, _8=296, Outstate=17500, _10=4200, Books=500, Personal=950, PhD=94, Terminal=95, _15=10.5, _16=35, Expend=11951, _18=79)
# The datavalues row by row Pandas(Index=116, Private='Yes', Apps=460, Accept=340, Enroll=167, Top10perc=14, Top25perc=45, _7=604, _8=350, Outstate=10740, _10=3676, Books=350, Personal=900, PhD=67, Terminal=71, _15=11.0, _16=27, Expend=7963, _18=74)
# The datavalues row by row Pandas(Index=117, Private='Yes', Apps=2174, Accept=1953, Enroll=557, Top10perc=35, Top25perc=68, _7=2332, _8=53, Outstate=15960, _10=5580, Books=700, Personal=1300, PhD=95, Terminal=95, _15=15.8, _16=32, Expend=11659, _18=77)
# The datavalues row by row Pandas(Index=118, Private='No', Apps=8065, Accept=5257, Enroll=2301, Top10perc=37, Top25perc=65, _7=11755, _8=770, Outstate=8116, _10=3610, Books=800, Personal=1618, PhD=82, Terminal=88, _15=18.0, _16=17, Expend=7597, _18=73)
# The datavalues row by row Pandas(Index=119, Private='No', Apps=689, Accept=561, Enroll=250, Top10perc=15, Top25perc=30, _7=1125, _8=422, Outstate=7168, _10=3689, Books=600, Personal=1900, PhD=67, Terminal=67, _15=18.1, _16=9, Expend=4417, _18=46)
# The datavalues row by row Pandas(Index=120, Private='Yes', Apps=1006, Accept=742, Enroll=275, Top10perc=29, Top25perc=60, _7=1127, _8=205, Outstate=13925, _10=4390, Books=500, Personal=2200, PhD=73, Terminal=86, _15=12.7, _16=32, Expend=10141, _18=67)
# The datavalues row by row Pandas(Index=121, Private='Yes', Apps=604, Accept=452, Enroll=295, Top10perc=15, Top25perc=47, _7=690, _8=222, Outstate=9888, _10=4502, Books=400, Personal=1000, PhD=64, Terminal=77, _15=12.1, _16=39, Expend=8741, _18=75)
# The datavalues row by row Pandas(Index=122, Private='Yes', Apps=2848, Accept=1319, Enroll=456, Top10perc=58, Top25perc=84, _7=1720, _8=35, Outstate=18930, _10=5590, Books=500, Personal=1000, PhD=83, Terminal=94, _15=10.2, _16=41, Expend=15954, _18=91)
# The datavalues row by row Pandas(Index=123, Private='Yes', Apps=4856, Accept=2492, Enroll=727, Top10perc=46, Top25perc=75, _7=2649, _8=25, Outstate=19510, _10=5565, Books=500, Personal=750, PhD=95, Terminal=98, _15=10.5, _16=45, Expend=15494, _18=93)
# The datavalues row by row Pandas(Index=124, Private='Yes', Apps=1432, Accept=888, Enroll=317, Top10perc=29, Top25perc=58, _7=1121, _8=493, Outstate=10860, _10=5760, Books=550, Personal=900, PhD=56, Terminal=62, _15=12.9, _16=23, Expend=8604, _18=96)
# The datavalues row by row Pandas(Index=125, Private='No', Apps=4772, Accept=3140, Enroll=1265, Top10perc=22, Top25perc=55, _7=6851, _8=1200, Outstate=6120, _10=3460, Books=666, Personal=2316, PhD=73, Terminal=78, _15=17.2, _16=18, Expend=4776, _18=51)
# The datavalues row by row Pandas(Index=126, Private='Yes', Apps=798, Accept=620, Enroll=238, Top10perc=14, Top25perc=41, _7=1165, _8=1232, Outstate=9800, _10=4430, Books=400, Personal=1150, PhD=46, Terminal=46, _15=11.1, _16=35, Expend=6889, _18=100)
# The datavalues row by row Pandas(Index=127, Private='Yes', Apps=946, Accept=648, Enroll=177, Top10perc=23, Top25perc=46, _7=707, _8=432, Outstate=11790, _10=5770, Books=500, Personal=1000, PhD=75, Terminal=77, _15=11.9, _16=35, Expend=10015, _18=83)
# The datavalues row by row Pandas(Index=128, Private='Yes', Apps=344, Accept=264, Enroll=97, Top10perc=11, Top25perc=42, _7=500, _8=331, Outstate=12600, _10=5520, Books=630, Personal=2250, PhD=77, Terminal=80, _15=10.4, _16=7, Expend=9773, _18=43)
# The datavalues row by row Pandas(Index=129, Private='Yes', Apps=457, Accept=356, Enroll=177, Top10perc=35, Top25perc=61, _7=667, _8=1983, Outstate=11180, _10=5620, Books=600, Personal=700, PhD=64, Terminal=64, _15=11.5, _16=32, Expend=7477, _18=75)
# The datavalues row by row Pandas(Index=130, Private='Yes', Apps=938, Accept=864, Enroll=511, Top10perc=29, Top25perc=62, _7=1715, _8=103, Outstate=12247, _10=4221, Books=500, Personal=600, PhD=70, Terminal=88, _15=13.1, _16=26, Expend=8847, _18=72)
# The datavalues row by row Pandas(Index=131, Private='Yes', Apps=511, Accept=411, Enroll=186, Top10perc=23, Top25perc=51, _7=1692, _8=562, Outstate=12224, _10=4440, Books=450, Personal=1000, PhD=63, Terminal=87, _15=11.5, _16=32, Expend=7315, _18=77)
# The datavalues row by row Pandas(Index=132, Private='Yes', Apps=444, Accept=359, Enroll=122, Top10perc=34, Top25perc=53, _7=493, _8=968, Outstate=10900, _10=5250, Books=380, Personal=1000, PhD=68, Terminal=70, _15=11.4, _16=23, Expend=9447, _18=78)
# The datavalues row by row Pandas(Index=133, Private='Yes', Apps=983, Accept=664, Enroll=249, Top10perc=23, Top25perc=57, _7=1698, _8=894, Outstate=9990, _10=5666, Books=800, Personal=1500, PhD=66, Terminal=71, _15=14.3, _16=28, Expend=6084, _18=64)
# The datavalues row by row Pandas(Index=134, Private='Yes', Apps=546, Accept=447, Enroll=189, Top10perc=16, Top25perc=42, _7=873, _8=683, Outstate=11138, _10=4138, Books=600, Personal=1200, PhD=40, Terminal=74, _15=14.0, _16=7, Expend=8820, _18=80)
# The datavalues row by row Pandas(Index=135, Private='Yes', Apps=141, Accept=118, Enroll=55, Top10perc=12, Top25perc=21, _7=201, _8=173, Outstate=8300, _10=4850, Books=450, Personal=1300, PhD=53, Terminal=53, _15=9.5, _16=19, Expend=6936, _18=76)
# The datavalues row by row Pandas(Index=136, Private='Yes', Apps=672, Accept=596, Enroll=278, Top10perc=29, Top25perc=60, _7=1350, _8=275, Outstate=11844, _10=3696, Books=450, Personal=1146, PhD=54, Terminal=76, _15=11.6, _16=33, Expend=8996, _18=72)
# The datavalues row by row Pandas(Index=137, Private='Yes', Apps=2994, Accept=1691, Enroll=659, Top10perc=70, Top25perc=95, _7=2675, _8=22, Outstate=18000, _10=6300, Books=400, Personal=900, PhD=92, Terminal=96, _15=11.3, _16=55, Expend=12138, _18=95)
# The datavalues row by row Pandas(Index=138, Private='No', Apps=7117, Accept=3106, Enroll=1217, Top10perc=68, Top25perc=88, _7=5186, _8=134, Outstate=11720, _10=4298, Books=600, Personal=800, PhD=89, Terminal=92, _15=12.1, _16=31, Expend=9534, _18=93)
# The datavalues row by row Pandas(Index=139, Private='Yes', Apps=2100, Accept=1883, Enroll=553, Top10perc=29, Top25perc=65, _7=1704, _8=1, Outstate=16240, _10=4690, Books=500, Personal=500, PhD=84, Terminal=96, _15=11.1, _16=43, Expend=14140, _18=69)
# The datavalues row by row Pandas(Index=140, Private='Yes', Apps=3207, Accept=1577, Enroll=490, Top10perc=56, Top25perc=87, _7=1892, _8=7, Outstate=17142, _10=4190, Books=450, Personal=1200, PhD=85, Terminal=97, _15=11.3, _16=51, Expend=14664, _18=84)
# The datavalues row by row Pandas(Index=141, Private='No', Apps=9478, Accept=6312, Enroll=2194, Top10perc=29, Top25perc=65, _7=15646, _8=1829, Outstate=8412, _10=4180, Books=470, Personal=1800, PhD=87, Terminal=89, _15=19.2, _16=10, Expend=7850, _18=59)
# The datavalues row by row Pandas(Index=142, Private='Yes', Apps=314, Accept=158, Enroll=132, Top10perc=10, Top25perc=28, _7=690, _8=5346, Outstate=8294, _10=3700, Books=400, Personal=900, PhD=87, Terminal=87, _15=15.3, _16=2, Expend=5015, _18=37)
# The datavalues row by row Pandas(Index=143, Private='Yes', Apps=737, Accept=614, Enroll=242, Top10perc=21, Top25perc=67, _7=968, _8=237, Outstate=10425, _10=3975, Books=500, Personal=1500, PhD=61, Terminal=77, _15=14.7, _16=34, Expend=8693, _18=76)
# The datavalues row by row Pandas(Index=144, Private='Yes', Apps=6756, Accept=1930, Enroll=871, Top10perc=78, Top25perc=96, _7=3376, _8=55, Outstate=18624, _10=6664, Books=550, Personal=300, PhD=97, Terminal=98, _15=5.9, _16=21, Expend=30639, _18=99)
# The datavalues row by row Pandas(Index=145, Private='Yes', Apps=281, Accept=266, Enroll=139, Top10perc=13, Top25perc=29, _7=1049, _8=181, Outstate=10500, _10=3750, Books=450, Personal=950, PhD=69, Terminal=75, _15=12.8, _16=18, Expend=6955, _18=45)
# The datavalues row by row Pandas(Index=146, Private='Yes', Apps=232, Accept=216, Enroll=106, Top10perc=16, Top25perc=34, _7=534, _8=172, Outstate=6900, _10=3800, Books=450, Personal=1825, PhD=67, Terminal=76, _15=12.1, _16=9, Expend=6875, _18=42)
# The datavalues row by row Pandas(Index=147, Private='Yes', Apps=688, Accept=497, Enroll=144, Top10perc=30, Top25perc=75, _7=641, _8=101, Outstate=10800, _10=4440, Books=570, Personal=1515, PhD=55, Terminal=60, _15=13.1, _16=13, Expend=8415, _18=55)
# The datavalues row by row Pandas(Index=148, Private='Yes', Apps=528, Accept=403, Enroll=186, Top10perc=22, Top25perc=56, _7=1168, _8=145, Outstate=9216, _10=4191, Books=400, Personal=1000, PhD=56, Terminal=64, _15=12.1, _16=13, Expend=7309, _18=75)
# The datavalues row by row Pandas(Index=149, Private='Yes', Apps=3035, Accept=1546, Enroll=438, Top10perc=42, Top25perc=93, _7=1630, _8=232, Outstate=18740, _10=6300, Books=600, Personal=500, PhD=86, Terminal=95, _15=10.7, _16=40, Expend=14773, _18=91)
# The datavalues row by row Pandas(Index=150, Private='Yes', Apps=440, Accept=407, Enroll=149, Top10perc=35, Top25perc=70, _7=643, _8=80, Outstate=12050, _10=3700, Books=500, Personal=900, PhD=63, Terminal=76, _15=10.2, _16=31, Expend=10965, _18=75)
# The datavalues row by row Pandas(Index=151, Private='Yes', Apps=1538, Accept=1329, Enroll=383, Top10perc=33, Top25perc=68, _7=1140, _8=10, Outstate=15248, _10=4323, Books=550, Personal=800, PhD=71, Terminal=76, _15=12.2, _16=31, Expend=10340, _18=64)
# The datavalues row by row Pandas(Index=152, Private='Yes', Apps=2967, Accept=2836, Enroll=876, Top10perc=30, Top25perc=60, _7=3450, _8=644, Outstate=10628, _10=4372, Books=650, Personal=2055, PhD=85, Terminal=90, _15=6.5, _16=32, Expend=22906, _18=85)
# The datavalues row by row Pandas(Index=153, Private='Yes', Apps=1576, Accept=1110, Enroll=274, Top10perc=24, Top25perc=55, _7=992, _8=112, Outstate=8000, _10=3700, Books=400, Personal=500, PhD=51, Terminal=52, _15=14.1, _16=28, Expend=5807, _18=51)
# The datavalues row by row Pandas(Index=154, Private='Yes', Apps=995, Accept=789, Enroll=398, Top10perc=26, Top25perc=47, _7=1306, _8=122, Outstate=6230, _10=3526, Books=400, Personal=600, PhD=42, Terminal=44, _15=13.0, _16=4, Expend=8189, _18=63)
# The datavalues row by row Pandas(Index=155, Private='Yes', Apps=866, Accept=619, Enroll=157, Top10perc=18, Top25perc=47, _7=1074, _8=336, Outstate=8920, _10=4310, Books=680, Personal=1320, PhD=68, Terminal=68, _15=14.6, _16=42, Expend=6898, _18=46)
# The datavalues row by row Pandas(Index=156, Private='Yes', Apps=504, Accept=482, Enroll=185, Top10perc=10, Top25perc=36, _7=550, _8=84, Outstate=9130, _10=3322, Books=450, Personal=1450, PhD=46, Terminal=51, _15=12.6, _16=25, Expend=8686, _18=54)
# The datavalues row by row Pandas(Index=157, Private='Yes', Apps=585, Accept=508, Enroll=153, Top10perc=12, Top25perc=30, _7=460, _8=536, Outstate=12292, _10=4934, Books=500, Personal=500, PhD=61, Terminal=61, _15=22.2, _16=10, Expend=8643, _18=72)
# The datavalues row by row Pandas(Index=158, Private='Yes', Apps=8587, Accept=2273, Enroll=1087, Top10perc=87, Top25perc=99, _7=3918, _8=32, Outstate=19545, _10=6070, Books=550, Personal=1100, PhD=95, Terminal=99, _15=4.7, _16=49, Expend=29619, _18=98)
# The datavalues row by row Pandas(Index=159, Private='Yes', Apps=2373, Accept=956, Enroll=452, Top10perc=77, Top25perc=96, _7=1601, _8=6, Outstate=17295, _10=5070, Books=600, Personal=1011, PhD=95, Terminal=97, _15=12.0, _16=46, Expend=17581, _18=94)
# The datavalues row by row Pandas(Index=160, Private='Yes', Apps=571, Accept=461, Enroll=174, Top10perc=10, Top25perc=26, _7=645, _8=283, Outstate=10850, _10=3670, Books=400, Personal=1159, PhD=58, Terminal=60, _15=12.8, _16=19, Expend=7505, _18=56)
# The datavalues row by row Pandas(Index=161, Private='No', Apps=967, Accept=945, Enroll=459, Top10perc=15, Top25perc=48, _7=2806, _8=538, Outstate=4528, _10=1880, Books=500, Personal=1200, PhD=49, Terminal=63, _15=17.1, _16=16, Expend=5113, _18=58)
# The datavalues row by row Pandas(Index=162, Private='Yes', Apps=2762, Accept=2279, Enroll=533, Top10perc=32, Top25perc=60, _7=1835, _8=14, Outstate=16900, _10=4720, Books=500, Personal=600, PhD=88, Terminal=97, _15=11.6, _16=45, Expend=12423, _18=81)
# The datavalues row by row Pandas(Index=163, Private='Yes', Apps=1994, Accept=1656, Enroll=495, Top10perc=50, Top25perc=80, _7=1983, _8=36, Outstate=14300, _10=5020, Books=550, Personal=950, PhD=78, Terminal=94, _15=11.1, _16=31, Expend=11525, _18=82)
# The datavalues row by row Pandas(Index=164, Private='Yes', Apps=3014, Accept=2539, Enroll=487, Top10perc=31, Top25perc=68, _7=1889, _8=62, Outstate=18700, _10=5000, Books=595, Personal=1250, PhD=87, Terminal=94, _15=11.2, _16=39, Expend=13861, _18=87)
# The datavalues row by row Pandas(Index=165, Private='No', Apps=434, Accept=412, Enroll=319, Top10perc=10, Top25perc=30, _7=1376, _8=237, Outstate=4486, _10=2146, Books=600, Personal=2000, PhD=50, Terminal=64, _15=16.5, _16=28, Expend=4525, _18=46)
# The datavalues row by row Pandas(Index=166, Private='Yes', Apps=1998, Accept=1376, Enroll=651, Top10perc=41, Top25perc=88, _7=1539, _8=45, Outstate=6700, _10=3650, Books=500, Personal=2307, PhD=52, Terminal=52, _15=14.1, _16=12, Expend=7566, _18=61)
# The datavalues row by row Pandas(Index=167, Private='Yes', Apps=793, Accept=709, Enroll=244, Top10perc=20, Top25perc=47, _7=1022, _8=411, Outstate=9570, _10=3000, Books=400, Personal=1000, PhD=67, Terminal=72, _15=15.1, _16=42, Expend=6852, _18=60)
# The datavalues row by row Pandas(Index=168, Private='Yes', Apps=360, Accept=329, Enroll=108, Top10perc=4, Top25perc=19, _7=756, _8=863, Outstate=8310, _10=5500, Books=600, Personal=1800, PhD=43, Terminal=43, _15=12.7, _16=5, Expend=5480, _18=54)
# The datavalues row by row Pandas(Index=169, Private='Yes', Apps=604, Accept=562, Enroll=328, Top10perc=25, Top25perc=50, _7=1048, _8=56, Outstate=9800, _10=2650, Books=450, Personal=2800, PhD=61, Terminal=60, _15=12.5, _16=17, Expend=7325, _18=87)
# The datavalues row by row Pandas(Index=170, Private='Yes', Apps=1011, Accept=829, Enroll=410, Top10perc=9, Top25perc=33, _7=1059, _8=2458, Outstate=9000, _10=3100, Books=450, Personal=1413, PhD=77, Terminal=78, _15=12.4, _16=7, Expend=11178, _18=42)
# The datavalues row by row Pandas(Index=171, Private='Yes', Apps=2799, Accept=2573, Enroll=839, Top10perc=34, Top25perc=65, _7=3322, _8=726, Outstate=13420, _10=4770, Books=560, Personal=1675, PhD=88, Terminal=93, _15=15.0, _16=24, Expend=9473, _18=77)
# The datavalues row by row Pandas(Index=172, Private='Yes', Apps=2153, Accept=1580, Enroll=321, Top10perc=56, Top25perc=84, _7=1192, _8=87, Outstate=18432, _10=5616, Books=520, Personal=660, PhD=93, Terminal=97, _15=10.2, _16=28, Expend=14907, _18=83)
# The datavalues row by row Pandas(Index=173, Private='Yes', Apps=700, Accept=650, Enroll=314, Top10perc=33, Top25perc=66, _7=1065, _8=48, Outstate=8730, _10=3523, Books=500, Personal=750, PhD=82, Terminal=92, _15=13.2, _16=35, Expend=9303, _18=67)
# The datavalues row by row Pandas(Index=174, Private='Yes', Apps=13789, Accept=3893, Enroll=1583, Top10perc=90, Top25perc=98, _7=6188, _8=53, Outstate=18590, _10=5950, Books=625, Personal=1162, PhD=95, Terminal=96, _15=5.0, _16=44, Expend=27206, _18=97)
# The datavalues row by row Pandas(Index=175, Private='Yes', Apps=1358, Accept=1006, Enroll=274, Top10perc=35, Top25perc=63, _7=1028, _8=13, Outstate=15036, _10=4056, Books=600, Personal=600, PhD=90, Terminal=94, _15=10.6, _16=46, Expend=14634, _18=78)
# The datavalues row by row Pandas(Index=176, Private='No', Apps=9274, Accept=6362, Enroll=2435, Top10perc=14, Top25perc=44, _7=13171, _8=1687, Outstate=7248, _10=3240, Books=500, Personal=1700, PhD=74, Terminal=78, _15=13.2, _16=18, Expend=9002, _18=58)
# The datavalues row by row Pandas(Index=177, Private='No', Apps=3330, Accept=2730, Enroll=1303, Top10perc=15, Top25perc=36, _7=6706, _8=2640, Outstate=5800, _10=3000, Books=600, Personal=2200, PhD=73, Terminal=75, _15=14.0, _16=9, Expend=9825, _18=42)
# The datavalues row by row Pandas(Index=178, Private='Yes', Apps=379, Accept=341, Enroll=265, Top10perc=10, Top25perc=36, _7=1050, _8=151, Outstate=4950, _10=2780, Books=530, Personal=1500, PhD=62, Terminal=62, _15=15.7, _16=7, Expend=5619, _18=38)
# The datavalues row by row Pandas(Index=179, Private='Yes', Apps=458, Accept=369, Enroll=165, Top10perc=16, Top25perc=42, _7=1057, _8=355, Outstate=11190, _10=4800, Books=450, Personal=1230, PhD=60, Terminal=60, _15=13.6, _16=22, Expend=8135, _18=54)
# The datavalues row by row Pandas(Index=180, Private='No', Apps=2172, Accept=1493, Enroll=564, Top10perc=14, Top25perc=50, _7=2766, _8=1531, Outstate=5962, _10=4316, Books=650, Personal=500, PhD=71, Terminal=76, _15=16.9, _16=14, Expend=5719, _18=50)
# The datavalues row by row Pandas(Index=181, Private='No', Apps=5597, Accept=4253, Enroll=1565, Top10perc=12, Top25perc=38, _7=9161, _8=845, Outstate=5710, _10=3066, Books=120, Personal=1730, PhD=62, Terminal=71, _15=16.2, _16=5, Expend=5682, _18=76)
# The datavalues row by row Pandas(Index=182, Private='Yes', Apps=486, Accept=440, Enroll=227, Top10perc=19, Top25perc=48, _7=903, _8=59, Outstate=9650, _10=3800, Books=600, Personal=1300, PhD=46, Terminal=65, _15=11.4, _16=29, Expend=10188, _18=82)
# The datavalues row by row Pandas(Index=183, Private='Yes', Apps=516, Accept=409, Enroll=200, Top10perc=17, Top25perc=40, _7=1238, _8=30, Outstate=8770, _10=3500, Books=450, Personal=700, PhD=58, Terminal=58, _15=17.3, _16=17, Expend=6430, _18=70)
# The datavalues row by row Pandas(Index=184, Private='Yes', Apps=1422, Accept=1109, Enroll=366, Top10perc=33, Top25perc=65, _7=1363, _8=23, Outstate=15360, _10=4080, Books=600, Personal=1000, PhD=82, Terminal=89, _15=12.8, _16=26, Expend=15003, _18=59)
# The datavalues row by row Pandas(Index=185, Private='Yes', Apps=2417, Accept=1843, Enroll=426, Top10perc=36, Top25perc=70, _7=1476, _8=299, Outstate=14190, _10=4400, Books=500, Personal=750, PhD=65, Terminal=68, _15=12.8, _16=25, Expend=9815, _18=81)
# The datavalues row by row Pandas(Index=186, Private='Yes', Apps=1457, Accept=1045, Enroll=345, Top10perc=27, Top25perc=50, _7=1109, _8=502, Outstate=14990, _10=4980, Books=450, Personal=550, PhD=77, Terminal=98, _15=21.5, _16=21, Expend=7502, _18=64)
# The datavalues row by row Pandas(Index=187, Private='Yes', Apps=245, Accept=208, Enroll=125, Top10perc=23, Top25perc=46, _7=544, _8=436, Outstate=11800, _10=4765, Books=450, Personal=1700, PhD=71, Terminal=71, _15=11.3, _16=21, Expend=8952, _18=86)
# The datavalues row by row Pandas(Index=188, Private='Yes', Apps=3624, Accept=2786, Enroll=858, Top10perc=11, Top25perc=39, _7=2933, _8=334, Outstate=9100, _10=3883, Books=490, Personal=1777, PhD=70, Terminal=74, _15=18.9, _16=34, Expend=6329, _18=63)
# The datavalues row by row Pandas(Index=189, Private='Yes', Apps=3151, Accept=2584, Enroll=958, Top10perc=14, Top25perc=40, _7=4772, _8=856, Outstate=7800, _10=3750, Books=570, Personal=3020, PhD=37, Terminal=43, _15=16.5, _16=4, Expend=12878, _18=44)
# The datavalues row by row Pandas(Index=190, Private='Yes', Apps=765, Accept=646, Enroll=226, Top10perc=30, Top25perc=60, _7=809, _8=32, Outstate=8578, _10=4408, Books=700, Personal=1600, PhD=79, Terminal=88, _15=13.9, _16=51, Expend=8061, _18=82)
# The datavalues row by row Pandas(Index=191, Private='Yes', Apps=8506, Accept=4168, Enroll=1236, Top10perc=76, Top25perc=97, _7=5544, _8=192, Outstate=17600, _10=6000, Books=600, Personal=870, PhD=97, Terminal=98, _15=5.0, _16=28, Expend=28457, _18=96)
# ...
# The datavalues row by row Pandas(Index=714, Private='Yes', Apps=1847, Accept=1610, Enroll=453, Top10perc=19, Top25perc=59, _7=1298, _8=67, Outstate=7384, _10=3494, Books=500, Personal=1763, PhD=51, Terminal=67, _15=13.7, _16=8, Expend=6757, _18=30)
# The datavalues row by row Pandas(Index=715, Private='Yes', Apps=1470, Accept=900, Enroll=287, Top10perc=20, Top25perc=49, _7=1130, _8=417, Outstate=10900, _10=5100, Books=500, Personal=550, PhD=70, Terminal=81, _15=15.7, _16=14, Expend=7804, _18=68)
# The datavalues row by row Pandas(Index=716, Private='Yes', Apps=647, Accept=518, Enroll=271, Top10perc=17, Top25perc=43, _7=1014, _8=387, Outstate=9140, _10=3365, Books=500, Personal=2245, PhD=51, Terminal=65, _15=10.7, _16=31, Expend=8050, _18=73)
# The datavalues row by row Pandas(Index=717, Private='Yes', Apps=1465, Accept=1006, Enroll=188, Top10perc=10, Top25perc=30, _7=703, _8=20, Outstate=4450, _10=2522, Books=500, Personal=1200, PhD=43, Terminal=43, _15=22.9, _16=3, Expend=5861, _18=58)
# The datavalues row by row Pandas(Index=718, Private='Yes', Apps=800, Accept=623, Enroll=256, Top10perc=41, Top25perc=76, _7=801, _8=5, Outstate=12925, _10=4195, Books=500, Personal=635, PhD=78, Terminal=85, _15=9.9, _16=55, Expend=14904, _18=72)
# The datavalues row by row Pandas(Index=719, Private='Yes', Apps=1416, Accept=1015, Enroll=417, Top10perc=10, Top25perc=44, _7=1324, _8=117, Outstate=13500, _10=5800, Books=585, Personal=1700, PhD=67, Terminal=78, _15=13.2, _16=23, Expend=9006, _18=75)
# The datavalues row by row Pandas(Index=720, Private='Yes', Apps=5661, Accept=2392, Enroll=903, Top10perc=75, Top25perc=88, _7=3499, _8=172, Outstate=13850, _10=4360, Books=500, Personal=1250, PhD=95, Terminal=97, _15=4.3, _16=37, Expend=41766, _18=89)
# The datavalues row by row Pandas(Index=721, Private='Yes', Apps=1092, Accept=890, Enroll=477, Top10perc=27, Top25perc=92, _7=847, _8=497, Outstate=8670, _10=4180, Books=500, Personal=1450, PhD=42, Terminal=58, _15=11.3, _16=33, Expend=5738, _18=68)
# The datavalues row by row Pandas(Index=722, Private='Yes', Apps=440, Accept=311, Enroll=112, Top10perc=25, Top25perc=49, _7=466, _8=7, Outstate=10000, _10=3052, Books=400, Personal=1100, PhD=65, Terminal=75, _15=11.4, _16=20, Expend=9430, _18=63)
# The datavalues row by row Pandas(Index=723, Private='Yes', Apps=1231, Accept=1074, Enroll=345, Top10perc=34, Top25perc=66, _7=1295, _8=105, Outstate=11600, _10=3610, Books=400, Personal=850, PhD=66, Terminal=91, _15=12.4, _16=37, Expend=7735, _18=67)
# The datavalues row by row Pandas(Index=724, Private='Yes', Apps=1305, Accept=1100, Enroll=334, Top10perc=42, Top25perc=64, _7=1098, _8=151, Outstate=16260, _10=4005, Books=300, Personal=500, PhD=91, Terminal=91, _15=12.1, _16=40, Expend=10162, _18=86)
# The datavalues row by row Pandas(Index=725, Private='Yes', Apps=3315, Accept=1096, Enroll=425, Top10perc=68, Top25perc=93, _7=1584, _8=3, Outstate=13750, _10=4619, Books=680, Personal=1115, PhD=81, Terminal=96, _15=9.6, _16=45, Expend=15736, _18=90)
# The datavalues row by row Pandas(Index=726, Private='Yes', Apps=1209, Accept=942, Enroll=214, Top10perc=31, Top25perc=60, _7=822, _8=46, Outstate=15276, _10=5318, Books=500, Personal=300, PhD=79, Terminal=86, _15=11.2, _16=37, Expend=10830, _18=65)
# The datavalues row by row Pandas(Index=727, Private='No', Apps=6540, Accept=5839, Enroll=2440, Top10perc=31, Top25perc=70, _7=14445, _8=1344, Outstate=8200, _10=4210, Books=800, Personal=2719, PhD=84, Terminal=87, _15=16.9, _16=30, Expend=10912, _18=56)
# The datavalues row by row Pandas(Index=728, Private='Yes', Apps=7654, Accept=5259, Enroll=1254, Top10perc=62, Top25perc=93, _7=4879, _8=1274, Outstate=18350, _10=5775, Books=768, Personal=1512, PhD=91, Terminal=98, _15=3.9, _16=31, Expend=45702, _18=90)
# The datavalues row by row Pandas(Index=729, Private='No', Apps=1373, Accept=1373, Enroll=724, Top10perc=6, Top25perc=21, _7=2754, _8=474, Outstate=2700, _10=2660, Books=540, Personal=1660, PhD=60, Terminal=68, _15=20.3, _16=29, Expend=4550, _18=52)
# The datavalues row by row Pandas(Index=730, Private='Yes', Apps=1190, Accept=978, Enroll=324, Top10perc=12, Top25perc=30, _7=1280, _8=61, Outstate=8840, _10=3620, Books=500, Personal=1200, PhD=57, Terminal=58, _15=16.2, _16=26, Expend=6563, _18=63)
# The datavalues row by row Pandas(Index=731, Private='Yes', Apps=280, Accept=143, Enroll=79, Top10perc=5, Top25perc=27, _7=327, _8=110, Outstate=5590, _10=2900, Books=650, Personal=1952, PhD=53, Terminal=63, _15=15.1, _16=4, Expend=4839, _18=90)
# The datavalues row by row Pandas(Index=732, Private='Yes', Apps=665, Accept=462, Enroll=226, Top10perc=17, Top25perc=44, _7=1739, _8=1550, Outstate=9160, _10=4340, Books=500, Personal=500, PhD=68, Terminal=68, _15=20.6, _16=14, Expend=6951, _18=48)
# The datavalues row by row Pandas(Index=733, Private='Yes', Apps=2895, Accept=1249, Enroll=579, Top10perc=80, Top25perc=96, _7=2195, _8=156, Outstate=18345, _10=5995, Books=500, Personal=700, PhD=94, Terminal=98, _15=10.6, _16=51, Expend=21409, _18=91)
# The datavalues row by row Pandas(Index=734, Private='Yes', Apps=318, Accept=240, Enroll=130, Top10perc=40, Top25perc=85, _7=416, _8=19, Outstate=14900, _10=5550, Books=600, Personal=500, PhD=93, Terminal=98, _15=8.3, _16=42, Expend=13935, _18=69)
# The datavalues row by row Pandas(Index=735, Private='Yes', Apps=1480, Accept=1257, Enroll=452, Top10perc=6, Top25perc=25, _7=2961, _8=572, Outstate=9850, _10=6050, Books=850, Personal=920, PhD=10, Terminal=68, _15=15.4, _16=8, Expend=17858, _18=64)
# The datavalues row by row Pandas(Index=736, Private='Yes', Apps=980, Accept=807, Enroll=350, Top10perc=10, Top25perc=25, _7=872, _8=448, Outstate=9890, _10=4674, Books=500, Personal=1350, PhD=52, Terminal=57, _15=14.4, _16=15, Expend=6243, _18=84)
# The datavalues row by row Pandas(Index=737, Private='Yes', Apps=4772, Accept=1973, Enroll=712, Top10perc=60, Top25perc=86, _7=2714, _8=27, Outstate=19130, _10=5600, Books=1400, Personal=1400, PhD=90, Terminal=94, _15=12.1, _16=39, Expend=16262, _18=92)
# The datavalues row by row Pandas(Index=738, Private='No', Apps=6502, Accept=3539, Enroll=1372, Top10perc=11, Top25perc=51, _7=7484, _8=1904, Outstate=7844, _10=4108, Books=400, Personal=2000, PhD=76, Terminal=79, _15=15.3, _16=16, Expend=6773, _18=52)
# The datavalues row by row Pandas(Index=739, Private='No', Apps=1164, Accept=1062, Enroll=478, Top10perc=12, Top25perc=25, _7=2138, _8=227, Outstate=4470, _10=2890, Books=600, Personal=1210, PhD=33, Terminal=33, _15=16.3, _16=10, Expend=4249, _18=60)
# The datavalues row by row Pandas(Index=740, Private='Yes', Apps=1566, Accept=1400, Enroll=483, Top10perc=28, Top25perc=55, _7=1509, _8=170, Outstate=14200, _10=3775, Books=450, Personal=1100, PhD=58, Terminal=81, _15=16.4, _16=42, Expend=8080, _18=67)
# The datavalues row by row Pandas(Index=741, Private='No', Apps=3224, Accept=2519, Enroll=1057, Top10perc=11, Top25perc=31, _7=5000, _8=706, Outstate=6390, _10=2380, Books=110, Personal=1622, PhD=67, Terminal=78, _15=14.6, _16=9, Expend=6554, _18=55)
# The datavalues row by row Pandas(Index=742, Private='Yes', Apps=1205, Accept=984, Enroll=278, Top10perc=31, Top25perc=50, _7=1071, _8=98, Outstate=14510, _10=5340, Books=500, Personal=1400, PhD=84, Terminal=91, _15=12.5, _16=39, Expend=10026, _18=60)
# The datavalues row by row Pandas(Index=743, Private='No', Apps=9167, Accept=7191, Enroll=2738, Top10perc=24, Top25perc=53, _7=15739, _8=4278, Outstate=6940, _10=4100, Books=500, Personal=1700, PhD=80, Terminal=84, _15=24.7, _16=11, Expend=5983, _18=55)
# The datavalues row by row Pandas(Index=744, Private='Yes', Apps=1650, Accept=1471, Enroll=409, Top10perc=7, Top25perc=21, _7=1803, _8=1116, Outstate=8994, _10=5500, Books=498, Personal=2065, PhD=74, Terminal=97, _15=15.4, _16=15, Expend=8409, _18=59)
# The datavalues row by row Pandas(Index=745, Private='No', Apps=2702, Accept=1623, Enroll=604, Top10perc=7, Top25perc=24, _7=2315, _8=146, Outstate=5918, _10=3755, Books=500, Personal=2050, PhD=76, Terminal=79, _15=19.4, _16=4, Expend=4599, _18=52)
# The datavalues row by row Pandas(Index=746, Private='No', Apps=5548, Accept=3563, Enroll=1549, Top10perc=30, Top25perc=71, _7=8909, _8=506, Outstate=8124, _10=4144, Books=639, Personal=2385, PhD=83, Terminal=89, _15=22.7, _16=10, Expend=7203, _18=61)
# The datavalues row by row Pandas(Index=747, Private='No', Apps=3100, Accept=2150, Enroll=825, Top10perc=3, Top25perc=20, _7=3234, _8=941, Outstate=5542, _10=3788, Books=500, Personal=1300, PhD=75, Terminal=79, _15=15.7, _16=20, Expend=4222, _18=65)
# The datavalues row by row Pandas(Index=748, Private='Yes', Apps=662, Accept=553, Enroll=184, Top10perc=20, Top25perc=43, _7=665, _8=37, Outstate=10720, _10=4050, Books=600, Personal=1650, PhD=66, Terminal=70, _15=12.5, _16=20, Expend=7925, _18=62)
# The datavalues row by row Pandas(Index=749, Private='Yes', Apps=996, Accept=866, Enroll=377, Top10perc=29, Top25perc=58, _7=1411, _8=72, Outstate=12065, _10=3615, Books=430, Personal=685, PhD=62, Terminal=78, _15=12.5, _16=41, Expend=8596, _18=80)
# The datavalues row by row Pandas(Index=750, Private='Yes', Apps=917, Accept=720, Enroll=213, Top10perc=21, Top25perc=60, _7=979, _8=743, Outstate=8820, _10=4050, Books=600, Personal=2025, PhD=68, Terminal=83, _15=10.5, _16=34, Expend=7170, _18=50)
# The datavalues row by row Pandas(Index=751, Private='No', Apps=950, Accept=713, Enroll=351, Top10perc=42, Top25perc=72, _7=1276, _8=9, Outstate=14320, _10=5304, Books=490, Personal=1410, PhD=77, Terminal=77, _15=14.9, _16=17, Expend=8837, _18=87)
# The datavalues row by row Pandas(Index=752, Private='Yes', Apps=1432, Accept=920, Enroll=548, Top10perc=56, Top25perc=84, _7=2200, _8=56, Outstate=11480, _10=4200, Books=530, Personal=1400, PhD=81, Terminal=83, _15=12.7, _16=40, Expend=11916, _18=85)
# The datavalues row by row Pandas(Index=753, Private='Yes', Apps=1738, Accept=1373, Enroll=417, Top10perc=21, Top25perc=55, _7=1335, _8=30, Outstate=18460, _10=5970, Books=700, Personal=850, PhD=92, Terminal=96, _15=13.2, _16=41, Expend=22704, _18=71)
# The datavalues row by row Pandas(Index=754, Private='Yes', Apps=903, Accept=755, Enroll=213, Top10perc=15, Top25perc=49, _7=971, _8=305, Outstate=10500, _10=4545, Books=600, Personal=600, PhD=66, Terminal=71, _15=14.1, _16=27, Expend=7494, _18=72)
# The datavalues row by row Pandas(Index=755, Private='Yes', Apps=1861, Accept=998, Enroll=359, Top10perc=45, Top25perc=77, _7=1220, _8=46, Outstate=16670, _10=4900, Books=750, Personal=800, PhD=80, Terminal=83, _15=10.5, _16=51, Expend=13198, _18=72)
# The datavalues row by row Pandas(Index=756, Private='Yes', Apps=1681, Accept=1069, Enroll=344, Top10perc=35, Top25perc=63, _7=1235, _8=30, Outstate=16249, _10=5699, Books=500, Personal=1998, PhD=84, Terminal=92, _15=13.6, _16=29, Expend=11778, _18=52)
# The datavalues row by row Pandas(Index=757, Private='Yes', Apps=1121, Accept=926, Enroll=372, Top10perc=43, Top25perc=70, _7=1270, _8=160, Outstate=12660, _10=4500, Books=678, Personal=2424, PhD=80, Terminal=80, _15=16.9, _16=20, Expend=8328, _18=80)
# The datavalues row by row Pandas(Index=758, Private='Yes', Apps=2139, Accept=1492, Enroll=502, Top10perc=24, Top25perc=64, _7=2186, _8=2171, Outstate=12350, _10=5370, Books=500, Personal=1350, PhD=88, Terminal=86, _15=12.6, _16=19, Expend=9603, _18=63)
# The datavalues row by row Pandas(Index=759, Private='Yes', Apps=1631, Accept=1431, Enroll=434, Top10perc=15, Top25perc=36, _7=1803, _8=603, Outstate=11150, _10=5130, Books=550, Personal=1260, PhD=78, Terminal=92, _15=13.3, _16=24, Expend=8543, _18=67)
# The datavalues row by row Pandas(Index=760, Private='Yes', Apps=1658, Accept=1327, Enroll=395, Top10perc=49, Top25perc=80, _7=1595, _8=159, Outstate=14800, _10=4620, Books=400, Personal=790, PhD=91, Terminal=94, _15=13.3, _16=37, Expend=10779, _18=68)
# The datavalues row by row Pandas(Index=761, Private='Yes', Apps=663, Accept=547, Enroll=315, Top10perc=32, Top25perc=67, _7=1279, _8=75, Outstate=10060, _10=2970, Books=500, Personal=2600, PhD=74, Terminal=80, _15=11.2, _16=19, Expend=7885, _18=59)
# The datavalues row by row Pandas(Index=762, Private='Yes', Apps=469, Accept=435, Enroll=227, Top10perc=17, Top25perc=39, _7=851, _8=120, Outstate=10535, _10=4365, Books=550, Personal=3700, PhD=39, Terminal=66, _15=12.9, _16=16, Expend=7438, _18=52)
# The datavalues row by row Pandas(Index=763, Private='Yes', Apps=4186, Accept=1245, Enroll=526, Top10perc=81, Top25perc=96, _7=1988, _8=29, Outstate=19629, _10=5790, Books=500, Personal=1200, PhD=94, Terminal=99, _15=9.0, _16=64, Expend=22014, _18=99)
# The datavalues row by row Pandas(Index=764, Private='Yes', Apps=167, Accept=130, Enroll=46, Top10perc=16, Top25perc=50, _7=199, _8=676, Outstate=11428, _10=5084, Books=450, Personal=475, PhD=67, Terminal=76, _15=8.3, _16=43, Expend=10291, _18=67)
# The datavalues row by row Pandas(Index=765, Private='Yes', Apps=1239, Accept=1017, Enroll=383, Top10perc=10, Top25perc=34, _7=1207, _8=157, Outstate=7820, _10=3400, Books=550, Personal=1550, PhD=69, Terminal=81, _15=13.9, _16=8, Expend=7264, _18=91)
# The datavalues row by row Pandas(Index=766, Private='No', Apps=3325, Accept=2047, Enroll=1301, Top10perc=20, Top25perc=45, _7=5800, _8=872, Outstate=4200, _10=2700, Books=300, Personal=1200, PhD=53, Terminal=60, _15=20.2, _16=18, Expend=5318, _18=58)
# The datavalues row by row Pandas(Index=767, Private='No', Apps=2320, Accept=1805, Enroll=769, Top10perc=24, Top25perc=61, _7=3395, _8=670, Outstate=6400, _10=3392, Books=580, Personal=2150, PhD=71, Terminal=80, _15=12.8, _16=26, Expend=6729, _18=59)
# The datavalues row by row Pandas(Index=768, Private='Yes', Apps=152, Accept=128, Enroll=75, Top10perc=17, Top25perc=41, _7=282, _8=22, Outstate=9100, _10=3700, Books=500, Personal=1400, PhD=48, Terminal=48, _15=8.5, _16=26, Expend=8960, _18=50)
# The datavalues row by row Pandas(Index=769, Private='Yes', Apps=1979, Accept=1739, Enroll=575, Top10perc=42, Top25perc=68, _7=1980, _8=144, Outstate=15948, _10=4404, Books=400, Personal=800, PhD=82, Terminal=95, _15=12.8, _16=29, Expend=10414, _18=78)
# The datavalues row by row Pandas(Index=770, Private='Yes', Apps=1501, Accept=935, Enroll=273, Top10perc=51, Top25perc=83, _7=1059, _8=34, Outstate=12680, _10=4150, Books=605, Personal=1440, PhD=91, Terminal=92, _15=15.3, _16=42, Expend=7875, _18=75)
# The datavalues row by row Pandas(Index=771, Private='Yes', Apps=2768, Accept=2314, Enroll=682, Top10perc=49, Top25perc=86, _7=2802, _8=86, Outstate=15884, _10=5370, Books=530, Personal=730, PhD=92, Terminal=94, _15=15.2, _16=34, Expend=10774, _18=82)
# The datavalues row by row Pandas(Index=772, Private='No', Apps=2197, Accept=1515, Enroll=543, Top10perc=4, Top25perc=26, _7=3089, _8=2029, Outstate=6797, _10=3900, Books=500, Personal=1200, PhD=60, Terminal=60, _15=21.0, _16=14, Expend=4469, _18=40)
# The datavalues row by row Pandas(Index=773, Private='Yes', Apps=1959, Accept=1805, Enroll=695, Top10perc=24, Top25perc=47, _7=2849, _8=1107, Outstate=11520, _10=4960, Books=600, Personal=1250, PhD=73, Terminal=75, _15=13.3, _16=31, Expend=9189, _18=83)
# The datavalues row by row Pandas(Index=774, Private='Yes', Apps=2097, Accept=1915, Enroll=695, Top10perc=34, Top25perc=61, _7=2793, _8=166, Outstate=6900, _10=4200, Books=617, Personal=781, PhD=67, Terminal=75, _15=14.4, _16=20, Expend=8323, _18=49)
# The datavalues row by row Pandas(Index=775, Private='Yes', Apps=10705, Accept=2453, Enroll=1317, Top10perc=95, Top25perc=99, _7=5217, _8=83, Outstate=19840, _10=6510, Books=630, Personal=2115, PhD=96, Terminal=96, _15=5.8, _16=49, Expend=40386, _18=99)
# The datavalues row by row Pandas(Index=776, Private='Yes', Apps=2989, Accept=1855, Enroll=691, Top10perc=28, Top25perc=63, _7=2988, _8=1726, Outstate=4990, _10=3560, Books=500, Personal=1250, PhD=75, Terminal=75, _15=18.1, _16=28, Expend=4509, _18=99)

# %% [markdown]
# # 3. Basic descriptive statistics using Data frame

# %% [markdown]
# ### 1. Basic statistical functions in Pandas

# %%
# Pandas provide basic statistical functions such as, mean(), median(), mode(), min(), max,()
# describe() to find mean, median, mode, min, max value of a specific feature.
# the desribe() function gives mean, standard deviation, max, min, quantiles in one
# command.

# %%
print("The mean of the feature Accept: ", dataset['Accept'].mean())
# Out:
# The mean of the feature Accept:  2018.8043758043757

# %%
print("The sum of the feature Accept: ", dataset['Accept'].sum())
# Out:
# The sum of the feature Accept:  1568611

# %%
print("The Standard Deviation of the feature Accept: ", dataset['Accept'].std())
# Out:
# The Standard Deviation of the feature Accept:  2451.113970992631

# %%
print("The min value of the feature Accept: ", dataset['Accept'].min())
# Out:
# The min value of the feature Accept:  72

# %%
print("The Statistical Description of all features: ", dataset.describe())
# Out:
# The Statistical Description of all features:                 Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# min      139.000000      1.000000   2340.000000  1780.000000    96.000000
# 25%      992.000000     95.000000   7320.000000  3597.000000   470.000000
# 50%     1707.000000    353.000000   9990.000000  4200.000000   500.000000
# 75%     4005.000000    967.000000  12925.000000  5050.000000   600.000000
# max    31643.000000  21836.000000  21700.000000  8124.000000  2340.000000
#
#           Personal         PhD    Terminal   S.F.Ratio  perc.alumni  \
# count   777.000000  777.000000  777.000000  777.000000   777.000000
# mean   1340.642214   72.660232   79.702703   14.089704    22.743887
# std     677.071454   16.328155   14.722359    3.958349    12.391801
# min     250.000000    8.000000   24.000000    2.500000     0.000000
# 25%     850.000000   62.000000   71.000000   11.500000    13.000000
# 50%    1200.000000   75.000000   82.000000   13.600000    21.000000
# 75%    1700.000000   85.000000   92.000000   16.500000    31.000000
# max    6800.000000  103.000000  100.000000   39.800000    64.000000
#
#              Expend  Grad.Rate
# count    777.000000  777.00000
# mean    9660.171171   65.46332
# std     5221.768440   17.17771
# min     3186.000000   10.00000
# 25%     6751.000000   53.00000
# 50%     8377.000000   65.00000
# 75%    10830.000000   78.00000
# max    56233.000000  118.00000

# %% [markdown]
# ### 2. Printing description of columns based in data type

# %%
# following code will print statistics of features of type object. 
dataset.describe(include=['object'])
# Out:
#        Private
# count      777
# unique       2
# top        Yes
# freq       565

# %% [markdown]
# ### 3. Printing description of categorical columns using value_counts() method

# %%
# following code will print statistics of features of type object.

dataset['Private'].value_counts()
# Out:
# Yes    565
# No     212
# Name: Private, dtype: int64

# %% [markdown]
# # 4. Data manipulation using Data frame

# %% [markdown]
# ### 1. Dataframe can be used to sort the value of one or more variable

# %%
# following code sort feature Apps

dataset.sort_values(by='Apps', ascending=True).head()
# Out:
#     Private  Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 110     Yes    81      72      51         33         71          139
# 85      Yes   100      90      35         10         52          282
# 135     Yes   141     118      55         12         21          201
# 500     Yes   150     130      88         23         50          341
# 768     Yes   152     128      75         17         41          282
#
#      P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# 110            3      8730        3600    400       800   92        92
# 85           331      8400        2812    300      2134   10        50
# 135          173      8300        4850    450      1300   53        53
# 500          768     10300        4130    500      1700   44        58
# 768           22      9100        3700    500      1400   48        48
#
#      S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 110        9.3           17   10922         58
# 85        12.1           24    7976         52
# 135        9.5           19    6936         76
# 500       10.2           37    9678         75
# 768        8.5           26    8960         50

# %%
# following code sorts feature Apps and Accept in ascending order

dataset.sort_values(by=['Apps', 'Accept'], ascending=True).head()
# Out:
#     Private  Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 110     Yes    81      72      51         33         71          139
# 85      Yes   100      90      35         10         52          282
# 135     Yes   141     118      55         12         21          201
# 500     Yes   150     130      88         23         50          341
# 768     Yes   152     128      75         17         41          282
#
#      P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# 110            3      8730        3600    400       800   92        92
# 85           331      8400        2812    300      2134   10        50
# 135          173      8300        4850    450      1300   53        53
# 500          768     10300        4130    500      1700   44        58
# 768           22      9100        3700    500      1400   48        48
#
#      S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 110        9.3           17   10922         58
# 85        12.1           24    7976         52
# 135        9.5           19    6936         76
# 500       10.2           37    9678         75
# 768        8.5           26    8960         50

# %% [markdown]
# ### 2. Manipulate columns of data frame using apply() function

# %%
# following code will add 15 to each column of the type 'int64' 

newdataset = dataset.apply(lambda x: x + 15
                          if x.dtype=='int64'
                          else x)
print(newdataset)
# Out:
#     Private   Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0       Yes   1675    1247     736         38         67         2900
# 1       Yes   2201    1939     527         31         44         2698
# 2       Yes   1443    1112     351         37         65         1051
# 3       Yes    432     364     152         75        104          525
# 4       Yes    208     161      70         31         59          264
# ..      ...    ...     ...     ...        ...        ...          ...
# 772      No   2212    1530     558         19         41         3104
# 773     Yes   1974    1820     710         39         62         2864
# 774     Yes   2112    1930     710         49         76         2808
# 775     Yes  10720    2468    1332        110        114         5232
# 776     Yes   3004    1870     706         43         78         3003
#
#      P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# 0            552      7455        3315    465      2215   85        93
# 1           1242     12295        6465    765      1515   44        45
# 2            114     11265        3765    415      1180   68        81
# 3             78     12975        5465    465       890  107       112
# 4            884      7575        4135    815      1515   91        87
# ..           ...       ...         ...    ...       ...  ...       ...
# 772         2044      6812        3915    515      1215   75        75
# 773         1122     11535        4975    615      1265   88        90
# 774          181      6915        4215    632       796   82        90
# 775           98     19855        6525    645      2130  111       111
# 776         1741      5005        3575    515      1265   90        90
#
#      S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0         18.1           27    7056         75
# 1         12.2           31   10542         71
# 2         12.9           45    8750         69
# 3          7.7           52   19031         74
# 4         11.9           17   10937         30
# ..         ...          ...     ...        ...
# 772       21.0           29    4484         55
# 773       13.3           46    9204         98
# 774       14.4           35    8338         64
# 775        5.8           64   40401        114
# 776       18.1           43    4524        114
#
# [777 rows x 18 columns]

# %% [markdown]
# ### 3. Manipulate columns of data frame using replace() function

# %%
# function is used to replace a string, regex, list, dictionary, series, number etc. from a dataframe

# the following code will find "yes" in dataframe and replace it with "TRUE"
dataset.replace(to_replace = "Yes", value="True")
# Out:
#     Private   Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0      True   1660    1232     721         23         52         2885
# 1      True   2186    1924     512         16         29         2683
# 2      True   1428    1097     336         22         50         1036
# 3      True    417     349     137         60         89          510
# 4      True    193     146      55         16         44          249
# ..      ...    ...     ...     ...        ...        ...          ...
# 772      No   2197    1515     543          4         26         3089
# 773    True   1959    1805     695         24         47         2849
# 774    True   2097    1915     695         34         61         2793
# 775    True  10705    2453    1317         95         99         5217
# 776    True   2989    1855     691         28         63         2988
#
#      P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# 0            537      7440        3300    450      2200   70        78
# 1           1227     12280        6450    750      1500   29        30
# 2             99     11250        3750    400      1165   53        66
# 3             63     12960        5450    450       875   92        97
# 4            869      7560        4120    800      1500   76        72
# ..           ...       ...         ...    ...       ...  ...       ...
# 772         2029      6797        3900    500      1200   60        60
# 773         1107     11520        4960    600      1250   73        75
# 774          166      6900        4200    617       781   67        75
# 775           83     19840        6510    630      2115   96        96
# 776         1726      4990        3560    500      1250   75        75
#
#      S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0         18.1           12    7041         60
# 1         12.2           16   10527         56
# 2         12.9           30    8735         54
# 3          7.7           37   19016         59
# 4         11.9            2   10922         15
# ..         ...          ...     ...        ...
# 772       21.0           14    4469         40
# 773       13.3           31    9189         83
# 774       14.4           20    8323         49
# 775        5.8           49   40386         99
# 776       18.1           28    4509         99
#
# [777 rows x 18 columns]

# %% [markdown]
# ### 4. Adding a new column to the existing dataframe in using insert() function

# %%
# the following code will add column "NewCol1" to the existing data frame with default value as 78 at
# the location decided by the first argument.
dataset.insert(loc = len(dataset.columns), column = "newCol", value=78)
dataset
# Out:
#     Private   Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0       Yes   1660    1232     721         23         52         2885
# 1       Yes   2186    1924     512         16         29         2683
# 2       Yes   1428    1097     336         22         50         1036
# 3       Yes    417     349     137         60         89          510
# 4       Yes    193     146      55         16         44          249
# ..      ...    ...     ...     ...        ...        ...          ...
# 772      No   2197    1515     543          4         26         3089
# 773     Yes   1959    1805     695         24         47         2849
# 774     Yes   2097    1915     695         34         61         2793
# 775     Yes  10705    2453    1317         95         99         5217
# 776     Yes   2989    1855     691         28         63         2988
#
#      P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# 0            537      7440        3300    450      2200   70        78
# 1           1227     12280        6450    750      1500   29        30
# 2             99     11250        3750    400      1165   53        66
# 3             63     12960        5450    450       875   92        97
# 4            869      7560        4120    800      1500   76        72
# ..           ...       ...         ...    ...       ...  ...       ...
# 772         2029      6797        3900    500      1200   60        60
# 773         1107     11520        4960    600      1250   73        75
# 774          166      6900        4200    617       781   67        75
# 775           83     19840        6510    630      2115   96        96
# 776         1726      4990        3560    500      1250   75        75
#
#      S.F.Ratio  perc.alumni  Expend  Grad.Rate  newcol  newCol
# 0         18.1           12    7041         60      78      78
# 1         12.2           16   10527         56      78      78
# 2         12.9           30    8735         54      78      78
# 3          7.7           37   19016         59      78      78
# 4         11.9            2   10922         15      78      78
# ..         ...          ...     ...        ...     ...     ...
# 772       21.0           14    4469         40      78      78
# 773       13.3           31    9189         83      78      78
# 774       14.4           20    8323         49      78      78
# 775        5.8           49   40386         99      78      78
# 776       18.1           28    4509         99      78      78
#
# [777 rows x 20 columns]

# %% [markdown]
# ### 5. Drop a column from existing data frame

# %%
# the following code will delete column 'newCol' from the dataframe
dataset.drop(columns=['newcol'])
# Out:
#     Private   Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0       Yes   1660    1232     721         23         52         2885
# 1       Yes   2186    1924     512         16         29         2683
# 2       Yes   1428    1097     336         22         50         1036
# 3       Yes    417     349     137         60         89          510
# 4       Yes    193     146      55         16         44          249
# ..      ...    ...     ...     ...        ...        ...          ...
# 772      No   2197    1515     543          4         26         3089
# 773     Yes   1959    1805     695         24         47         2849
# 774     Yes   2097    1915     695         34         61         2793
# 775     Yes  10705    2453    1317         95         99         5217
# 776     Yes   2989    1855     691         28         63         2988
#
#      P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# 0            537      7440        3300    450      2200   70        78
# 1           1227     12280        6450    750      1500   29        30
# 2             99     11250        3750    400      1165   53        66
# 3             63     12960        5450    450       875   92        97
# 4            869      7560        4120    800      1500   76        72
# ..           ...       ...         ...    ...       ...  ...       ...
# 772         2029      6797        3900    500      1200   60        60
# 773         1107     11520        4960    600      1250   73        75
# 774          166      6900        4200    617       781   67        75
# 775           83     19840        6510    630      2115   96        96
# 776         1726      4990        3560    500      1250   75        75
#
#      S.F.Ratio  perc.alumni  Expend  Grad.Rate  newCol
# 0         18.1           12    7041         60      78
# 1         12.2           16   10527         56      78
# 2         12.9           30    8735         54      78
# 3          7.7           37   19016         59      78
# 4         11.9            2   10922         15      78
# ..         ...          ...     ...        ...     ...
# 772       21.0           14    4469         40      78
# 773       13.3           31    9189         83      78
# 774       14.4           20    8323         49      78
# 775        5.8           49   40386         99      78
# 776       18.1           28    4509         99      78
#
# [777 rows x 19 columns]

# %%
dataset.drop(columns=['newCol'])
# Out:
#     Private   Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0       Yes   1660    1232     721         23         52         2885
# 1       Yes   2186    1924     512         16         29         2683
# 2       Yes   1428    1097     336         22         50         1036
# 3       Yes    417     349     137         60         89          510
# 4       Yes    193     146      55         16         44          249
# ..      ...    ...     ...     ...        ...        ...          ...
# 772      No   2197    1515     543          4         26         3089
# 773     Yes   1959    1805     695         24         47         2849
# 774     Yes   2097    1915     695         34         61         2793
# 775     Yes  10705    2453    1317         95         99         5217
# 776     Yes   2989    1855     691         28         63         2988
#
#      P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# 0            537      7440        3300    450      2200   70        78
# 1           1227     12280        6450    750      1500   29        30
# 2             99     11250        3750    400      1165   53        66
# 3             63     12960        5450    450       875   92        97
# 4            869      7560        4120    800      1500   76        72
# ..           ...       ...         ...    ...       ...  ...       ...
# 772         2029      6797        3900    500      1200   60        60
# 773         1107     11520        4960    600      1250   73        75
# 774          166      6900        4200    617       781   67        75
# 775           83     19840        6510    630      2115   96        96
# 776         1726      4990        3560    500      1250   75        75
#
#      S.F.Ratio  perc.alumni  Expend  Grad.Rate  newcol
# 0         18.1           12    7041         60      78
# 1         12.2           16   10527         56      78
# 2         12.9           30    8735         54      78
# 3          7.7           37   19016         59      78
# 4         11.9            2   10922         15      78
# ..         ...          ...     ...        ...     ...
# 772       21.0           14    4469         40      78
# 773       13.3           31    9189         83      78
# 774       14.4           20    8323         49      78
# 775        5.8           49   40386         99      78
# 776       18.1           28    4509         99      78
#
# [777 rows x 19 columns]

# %% [markdown]
# ### 6. Drop a specific row from existing data frame

# %%
# following code will drop 0 and 1 row from the dataframe

dataset.drop([0,1])
# Out:
#     Private   Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 2       Yes   1428    1097     336         22         50         1036
# 3       Yes    417     349     137         60         89          510
# 4       Yes    193     146      55         16         44          249
# 5       Yes    587     479     158         38         62          678
# 6       Yes    353     340     103         17         45          416
# ..      ...    ...     ...     ...        ...        ...          ...
# 772      No   2197    1515     543          4         26         3089
# 773     Yes   1959    1805     695         24         47         2849
# 774     Yes   2097    1915     695         34         61         2793
# 775     Yes  10705    2453    1317         95         99         5217
# 776     Yes   2989    1855     691         28         63         2988
#
#      P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# 2             99     11250        3750    400      1165   53        66
# 3             63     12960        5450    450       875   92        97
# 4            869      7560        4120    800      1500   76        72
# 5             41     13500        3335    500       675   67        73
# 6            230     13290        5720    500      1500   90        93
# ..           ...       ...         ...    ...       ...  ...       ...
# 772         2029      6797        3900    500      1200   60        60
# 773         1107     11520        4960    600      1250   73        75
# 774          166      6900        4200    617       781   67        75
# 775           83     19840        6510    630      2115   96        96
# 776         1726      4990        3560    500      1250   75        75
#
#      S.F.Ratio  perc.alumni  Expend  Grad.Rate  newcol  newCol
# 2         12.9           30    8735         54      78      78
# 3          7.7           37   19016         59      78      78
# 4         11.9            2   10922         15      78      78
# 5          9.4           11    9727         55      78      78
# 6         11.5           26    8861         63      78      78
# ..         ...          ...     ...        ...     ...     ...
# 772       21.0           14    4469         40      78      78
# 773       13.3           31    9189         83      78      78
# 774       14.4           20    8323         49      78      78
# 775        5.8           49   40386         99      78      78
# 776       18.1           28    4509         99      78      78
#
# [775 rows x 20 columns]
